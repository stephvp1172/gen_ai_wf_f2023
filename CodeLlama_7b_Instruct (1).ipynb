# %% [markdown]
# # Text Generation: How to run inference on the endpoint you have created?

# %%
import json
import boto3

# %% [markdown]
# ### Query endpoint that you have created
# ***
# The following cell provides a helper function that will be used to query your endpoint with boto3.
# ***

# %%
endpoint_name = 'jumpstart-dft-llama-codellama-7b-instruct'

def query_endpoint(payload):
    client = boto3.client('runtime.sagemaker')
    response = client.invoke_endpoint(
        EndpointName=endpoint_name,
        ContentType='application/json',
        Body=json.dumps(payload).encode('utf-8'),
        CustomAttributes="accept_eula=true",
    )
    response = response["Body"].read().decode("utf8")
    response = json.loads(response)
    return response

# %% [markdown]
# ### Supported parameters
#
# ***
# This model supports many parameters while performing inference. They include:
#
# * **max_length:** Model generates text until the output length (which includes the input context length) reaches `max_length`. If specified, it must be a positive integer.
# * **max_new_tokens:** Model generates text until the output length (excluding the input context length) reaches `max_new_tokens`. If specified, it must be a positive integer.
# * **num_beams:** Number of beams used in the greedy search. If specified, it must be integer greater than or equal to `num_return_sequences`.
# * **no_repeat_ngram_size:** Model ensures that a sequence of words of `no_repeat_ngram_size` is not repeated in the output sequence. If specified, it must be a positive integer greater than 1.
# * **temperature:** Controls the randomness in the output. Higher temperature results in output sequence with low-probability words and lower temperature results in output sequence with high-probability words. If `temperature` -> 0, it results in greedy decoding. If specified, it must be a positive float.
# * **early_stopping:** If True, text generation is finished when all beam hypotheses reach the end of sentence token. If specified, it must be boolean.
# * **do_sample:** If True, sample the next word as per the likelihood. If specified, it must be boolean.
# * **top_k:** In each step of text generation, sample from only the `top_k` most likely words. If specified, it must be a positive integer.
# * **top_p:** In each step of text generation, sample from the smallest possible set of words with cumulative probability `top_p`. If specified, it must be a float between 0 and 1.
# * **return_full_text:** If True, input text will be part of the output generated text. If specified, it must be boolean. The default value for it is False.
# * **stop**: If specified, it must a list of strings. Text generation stops if any one of the specified strings is generated.
#
# We may specify any subset of the parameters mentioned above while invoking an endpoint. Next, we show an example of how to invoke endpoint with these arguments.
# ***

# %% [markdown]
# ## Code completion
# ***
# The examples in this section demonstrate how to perform code generation where the expected endpoint response is the natural continuation of the prompt.
# ***

# %%
def print_completion(prompt: str, response: str) -> None:
    bold, unbold = '\033[1m', '\033[0m'
    print(f"{bold}> Input{unbold}\n{prompt}{bold}\n> Output{unbold}\n{response['generated_text']}\n")

# %%
# %%time

prompt = """\
import socket

def ping_exponential_backoff(host: str):\
"""

payload = {"inputs": prompt, "parameters": {"max_new_tokens": 256, "temperature": 0.2, "top_p": 0.9}}
response = query_endpoint(payload)
print_completion(prompt, response)
# Out:
# > Input
# import socket
#
# def ping_exponential_backoff(host: str):
# > Output
#
#     """
#     Ping a host with exponential backoff.
#     :param host: The host to ping.
#     :return: The response time in milliseconds.
#     """
#     # Setup the socket.
#     sock = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
#     sock.settimeout(1)
#
#     # Setup the exponential backoff.
#     backoff = 1
#
#     # Ping the host.
#     while True:
#         try:
#             start = time.time()
#             sock.sendto(b'', (host, 0))
#             sock.recv(1024)
#             end = time.time()
#             return (end - start) * 1000
#         except socket.timeout:
#             # Wait for the backoff time.
#             time.sleep(backoff)
#
#             # Increase the backoff.
#             backoff *= 2
#
#
# def ping_exponential_backoff_with_timeout(host: str, timeout: float):
#     """
#     Ping
#
# CPU times: user 113 ms, sys: 18.5 ms, total: 132 ms
# Wall time: 8.34 s

# %%
# %%time

prompt = """\
import argparse

def main(string: str):
    print(string)
    print(string[::-1])

if __name__ == "__main__":\
"""

payload = {"inputs": prompt, "parameters": {"max_new_tokens": 256, "temperature": 0.2, "top_p": 0.9}}
response = query_endpoint(payload)
print_completion(prompt, response)
# Out:
# > Input
# import argparse
#
# def main(string: str):
#     print(string)
#     print(string[::-1])
#
# if __name__ == "__main__":
# > Output
#
#     parser = argparse.ArgumentParser(description='Reverse a string')
#     parser.add_argument('string', type=str, help='String to reverse')
#     args = parser.parse_args()
#     main(args.string)
#
# CPU times: user 20.3 ms, sys: 2.81 ms, total: 23.2 ms
# Wall time: 1.84 s

# %% [markdown]
# ## Code infilling
# ***
# The examples in this section demonstrate how to perform code generation where the expected endpoint response infills text between a prefix and a suffix. Only 7B, 7B-Instruct, 13B, and 13B-Instruct models have this capability, while the non-instruct models have been observed to obtain the best anecdotal performance.
# ***

# %%
def format_infilling(prompt: str) -> str:
    prefix, suffix = prompt.split("<FILL>")
    return f"<PRE> {prefix} <SUF>{suffix} <MID>"


def print_infilling(prompt: str, response: str) -> str:
    green, font_reset = "\x1b[38;5;2m", "\x1b[0m"
    prefix, suffix = prompt.split("<FILL>")
    print(f"{prefix}{green}{response['generated_text']}{font_reset}{suffix}")

# %%
# %%time

prompt = '''\
def remove_non_ascii(s: str) -> str:
    """<FILL>
    return result
'''
prompt_formatted = format_infilling(prompt)
payload = {
    "inputs": prompt_formatted,
    "parameters": {"max_new_tokens": 256, "temperature": 0.05, "top_p": 0.9}
}
response = query_endpoint(payload)
print_infilling(prompt, response)
# Out:
# def remove_non_ascii(s: str) -> str:
#     """
#     Remove non-ASCII characters from a string.
#     """
#     result = ""
#     for c in s:
#         if ord(c) < 128:
#             result += c
#     return result
#
#
# def remove_non_ascii_and_spaces(s: str) -> str:
#     """
#     Remove non-ASCII characters and spaces from a string.
#     """
#     result = ""
#     for c in s:
#         if ord(c) < 128 and c != " ":
#             result += c
#     return result
#
#
# def remove_non_ascii_and_spaces_and_newlines(s: str) -> str:
#     """
#     Remove non-ASCII characters, spaces and newlines from a string.
#     """
#     result = ""
#     for c in s:
#         if ord(c) < 128 and c not in [" ", "\n"]:
#             result += c
#     return result
#
#
# def remove_non_ascii_and_spaces_and_newlines_and_tabs(s: str) -> str:
#     """
#     return result
#
# CPU times: user 18.2 ms, sys: 260 µs, total: 18.5 ms
# Wall time: 8.01 s

# %%
# %%time

prompt = """\
# Installation instructions:
    ```bash
<FILL>
    ```
This downloads the LLaMA inference code and installs the repository as a local pip package.
"""
prompt_formatted = format_infilling(prompt)
payload = {
    "inputs": prompt_formatted,
    "parameters": {"max_new_tokens": 256, "temperature": 0.05, "top_p": 0.9}
}
response = query_endpoint(payload)
print_infilling(prompt, response)
# Out:
# # Installation instructions:
#     ```bash
#    git clone https://github.com/facebookresearch/LLaMA.git
#     cd LLaMA
#     pip install -e .
#     ```
#
# # Installation instructions for developers:
#     ```bash
#     git clone https://github.com/facebookresearch/LLaMA.git
#     cd LLaMA
#     pip install -e .[dev]
#     ```
#
# # Installation instructions for users:
#     ```bash
#     pip install lamalib
#     ```
#
# # Installation instructions for users (with GPU support):
#     ```bash
#     pip install lamalib[gpu]
#     ```
#
# # Installation instructions for users (with TensorFlow support):
#     ```bash
#     pip install lamalib[tf]
#     ```
#
# # Installation instructions for users (with TensorFlow and GPU support):
#     ```bash
#     pip install lamalib[tf,gpu]
#     ```
#
# # Installation instructions for users (with PyTorch support):
#     ```bash
#     pip install lamalib[pt]
#     ```
#
# # Installation instructions for users (with Py
#     ```
# This downloads the LLaMA inference code and installs the repository as a local pip package.
#
# CPU times: user 20 ms, sys: 2.51 ms, total: 22.5 ms
# Wall time: 8.04 s

# %%
# %%time

prompt = """\
class InterfaceManagerFactory(AbstractManagerFactory):
    def __init__(<FILL>
def main():
    factory = InterfaceManagerFactory(start=datetime.now())
    managers = []
    for i in range(10):
        managers.append(factory.build(id=i))
"""
prompt_formatted = format_infilling(prompt)
payload = {
    "inputs": prompt_formatted,
    "parameters": {"max_new_tokens": 256, "temperature": 0.05, "top_p": 0.9}
}
response = query_endpoint(payload)
print_infilling(prompt, response)
# Out:
# class InterfaceManagerFactory(AbstractManagerFactory):
#     def __init__(self, start=None):
#         self.start = start
#
#     def build(self, id):
#         return InterfaceManager(id, self.start)
#
#
# class InterfaceManager(AbstractManager):
#     def __init__(self, id, start):
#         self.id = id
#         self.start = start
#
#     def run(self):
#         print("Running interface manager %s" % self.id)
#
#
# if __name__ == "__main__":
#     main()
#
#
# # ------------------------------------------------------------------------------
# #
# # TESTS
# #
# # ------------------------------------------------------------------------------
#
#
# def test_interface_manager_factory():
#     factory = InterfaceManagerFactory(start=datetime.now())
#     managers = []
#     for i in range(10):
#         managers.append(factory.build(id=i))
#
#     for manager in managers:
#         manager.run()
#
#
# # ------------------------------------------------------------------------------
# #
# # MAIN
# #
# # ------------------------------------------------------------------------------
#
#
# if __name__ == "__main__":
#     test
# def main():
#     factory = InterfaceManagerFactory(start=datetime.now())
#     managers = []
#     for i in range(10):
#         managers.append(factory.build(id=i))
#
# CPU times: user 18.3 ms, sys: 3.05 ms, total: 21.4 ms
# Wall time: 8.04 s

# %%
# %%time

prompt = """\
/-- A quasi-prefunctoid is 1-connected iff all its etalisations are 1-connected. -/
theorem connected_iff_etalisation [C D : precategoroid] (P : quasi_prefunctoid C D) :
  π₁ P = 0 ↔ <FILL> = 0 :=
begin
  split,
  { intros h f,
    rw pi_1_etalisation at h,
    simp [h],
    refl
  },
  { intro h,
    have := @quasi_adjoint C D P,
    simp [←pi_1_etalisation, this, h],
    refl
  }
end
"""
prompt_formatted = format_infilling(prompt)
payload = {
    "inputs": prompt_formatted,
    "parameters": {"max_new_tokens": 256, "temperature": 0.05, "top_p": 0.9}
}
response = query_endpoint(payload)
print_infilling(prompt, response)
# Out:
# /-- A quasi-prefunctoid is 1-connected iff all its etalisations are 1-connected. -/
# theorem connected_iff_etalisation [C D : precategoroid] (P : quasi_prefunctoid C D) :
#   π₁ P = 0 ↔ π₁ (etalise P) = 0 :=
# begin
#   split,
#   { intros h f,
#     rw pi_1_etalisation at h,
#     simp [h],
#     refl
#   },
#   { intro h,
#     have := @quasi_adjoint C D P,
#     simp [←pi_1_etalisation, this, h],
#     refl
#   }
# end
#
# /-- A quasi-prefunctoid is 1-connected iff all its etalisations are 1-connected. -/
# theorem connected_iff_etalisation' [C D : precategoroid] (P : quasi_prefunctoid C D) :
#   π₁ P = 0 ↔ π₁ (etalise P) = 0 :=
# begin
#   split,
#   { intros h f,
#     rw pi_1_etalisation at h,
#     simp [h],
#     refl
#   },
#   { intro h,
#     have := @quasi_adjoint C D P,
#     simp [←pi_1_etalisation, this, h],
#     re = 0 :=
# begin
#   split,
#   { intros h f,
#     rw pi_1_etalisation at h,
#     simp [h],
#     refl
#   },
#   { intro h,
#     have := @quasi_adjoint C D P,
#     simp [←pi_1_etalisation, this, h],
#     refl
#   }
# end
#
# CPU times: user 22.7 ms, sys: 1.01 ms, total: 23.7 ms
# Wall time: 8.12 s

# %% [markdown]
# ## Code instructions
# ***
# The examples in this section demonstrate how to perform code generation where the expected endpoint response infills text between a prefix and a suffix.
# The CodeLlama format for instructions is the same as the Llama-2 Chat prompt format. These code instructions can only be applied to the instruction-tuned CodeLlama models, which are the models with a model ID `instruct` suffix.
# ***

# %%
from typing import Dict, List


def format_instructions(instructions: List[Dict[str, str]]) -> List[str]:
    """Format instructions for CodeLlama.
    
    The model only supports 'system', 'user' and 'assistant' roles, starting with 'system', then 'user' and 
    alternating (u/a/u/a/u...). The last message must be from 'user'.
    """
    prompt: List[str] = []

    if instructions[0]["role"] == "system":
        content = "".join(["<<SYS>>\n", instructions[0]["content"], "\n<</SYS>>\n\n", instructions[1]["content"]])
        instructions = [{"role": instructions[1]["role"], "content": content}] + instructions[2:]

    for user, answer in zip(instructions[::2], instructions[1::2]):
        prompt.extend(["<s>", "[INST] ", (user["content"]).strip(), " [/INST] ", (answer["content"]).strip(), "</s>"])

    prompt.extend(["<s>", "[INST] ", (instructions[-1]["content"]).strip(), " [/INST] "])

    return "".join(prompt)


def print_instructions(prompt: str, response: str) -> None:
    bold, unbold = '\033[1m', '\033[0m'
    print(f"{bold}> Input{unbold}\n{prompt}\n\n{bold}> Output{unbold}\n{response['generated_text']}\n")

# %%
# %%time

instructions = [
    {
        "role": "user",
        "content": "In Bash, how do I list all text files in the current directory (excluding subdirectories) that have been modified in the last month?",
    }
]
prompt = format_instructions(instructions)
payload = {
    "inputs": prompt,
    "parameters": {"max_new_tokens": 256, "temperature": 0.2, "top_p": 0.9}
}
response = query_endpoint(payload)
print_instructions(prompt, response)
# Out:
# > Input
# <s>[INST] In Bash, how do I list all text files in the current directory (excluding subdirectories) that have been modified in the last month? [/INST]
#
# > Output
#  You can use the `find` command in Bash to list all text files in the current directory (excluding subdirectories) that have been modified in the last month. Here's an example command:
# ```
# find . -type f -name "*.txt" -mtime -30
# ```
# Here's what each part of the command does:
#
# * `.`: This is the current directory.
# * `-type f`: This option tells `find` to only search for files (not directories).
# * `-name "*.txt"`: This option tells `find` to only search for files with the `.txt` extension.
# * `-mtime -30`: This option tells `find` to only search for files that have been modified in the last 30 days.
#
# The `-mtime` option takes a numerical argument, which specifies the number of days. In this case, `-30` means "modified in the last 30 days".
#
# You can also use `-mtime +30` to search for files that have been modified more than 30 days ago.
#
# You can also use `-mtime 0` to search for files that have been
#
# CPU times: user 17.7 ms, sys: 2.56 ms, total: 20.2 ms
# Wall time: 8.01 s

# %%
# %%time

instructions = [
    {
        "role": "user",
        "content": "What is the difference between inorder and preorder traversal? Give an example in Python.",
    }
]
prompt = format_instructions(instructions)
payload = {
    "inputs": prompt,
    "parameters": {"max_new_tokens": 256, "temperature": 0.2, "top_p": 0.9}
}
response = query_endpoint(payload)
print_instructions(prompt, response)
# Out:
# > Input
# <s>[INST] What is the difference between inorder and preorder traversal? Give an example in Python. [/INST]
#
# > Output
#  Inorder and preorder traversal are two different ways of traversing a binary tree.
#
# Inorder traversal visits the left subtree, then the root, and finally the right subtree. The order of the traversal is: left, root, right.
#
# Preorder traversal visits the root, then the left subtree, and finally the right subtree. The order of the traversal is: root, left, right.
#
# Here is an example of inorder and preorder traversal in Python:
# ```
# def inorder_traversal(root):
#     if root:
#         inorder_traversal(root.left)
#         print(root.data)
#         inorder_traversal(root.right)
#
# def preorder_traversal(root):
#     if root:
#         print(root.data)
#         preorder_traversal(root.left)
#         preorder_traversal(root.right)
# ```
# In the example above, `inorder_traversal` visits the left subtree, then the root, and finally the right subtree. `preorder_traversal`
#
# CPU times: user 24.1 ms, sys: 49 µs, total: 24.1 ms
# Wall time: 8 s

# %%
# %%time

instructions = [
    {
        "role": "system",
        "content": "Provide answers in JavaScript",
    },
    {
        "role": "user",
        "content": "Write a function that computes the set of sums of all contiguous sublists of a given list.",
    }
]
prompt = format_instructions(instructions)
payload = {
    "inputs": prompt,
    "parameters": {"max_new_tokens": 256, "temperature": 0.2, "top_p": 0.9}
}
response = query_endpoint(payload)
print_instructions(prompt, response)
# Out:
# > Input
# <s>[INST] <<SYS>>
# Provide answers in JavaScript
# <</SYS>>
#
# Write a function that computes the set of sums of all contiguous sublists of a given list. [/INST]
#
# > Output
#  Here's a possible implementation of the function in JavaScript:
# ```
# function contiguousSums(list) {
#   const sums = [];
#   for (let i = 0; i < list.length; i++) {
#     let sum = 0;
#     for (let j = i; j < list.length; j++) {
#       sum += list[j];
#     }
#     sums.push(sum);
#   }
#   return sums;
# }
# ```
# This function takes a list as input and returns a list of all the sums of contiguous sublists of the input list.
#
# For example, if the input list is `[1, 2, 3, 4, 5]`, the output list would be `[15, 14, 12, 7, 3, 0]`.
#
# Here's an explanation of how the function works:
#
# 1. We initialize an empty list `sums` to store the results.
# 2. We iterate over the input list `list` and for each element `list[i]`, we compute the sum of all elements from `list[i]` to the end of
#
# CPU times: user 19.5 ms, sys: 0 ns, total: 19.5 ms
# Wall time: 8 s

# %% [markdown]
# ## Importing Dataset

# %%
import pandas as pd

bucket='s3://complaints.csv'
data_key = 'complaints.csv'
data_location = 's3://{}/{}'.format(bucket, data_key)

data = pd.read_csv(data_location)

# %%
data.head(10)
# Out:
#   Date received                                            Product  \
# 0       4/26/18                        Credit card or prepaid card
# 1       7/18/23  Credit reporting, credit repair services, or o...
# 2      11/17/17                        Checking or savings account
# 3       1/21/21  Money transfer, virtual currency, or money ser...
# 4       9/23/14                            Bank account or service
# 5       8/23/20                        Credit card or prepaid card
# 6       7/26/22  Credit reporting, credit repair services, or o...
# 7       2/14/23  Credit reporting, credit repair services, or o...
# 8       5/22/19                                           Mortgage
# 9        5/4/23                        Checking or savings account
#
#                                   Sub-product  \
# 0  General-purpose credit card or charge card
# 1                            Credit reporting
# 2                            Checking account
# 3                Domestic (US) money transfer
# 4                            Checking account
# 5  General-purpose credit card or charge card
# 6                            Credit reporting
# 7                            Credit reporting
# 8                  Conventional home mortgage
# 9                            Checking account
#
#                                                Issue  \
# 0                                   Fees or interest
# 1                        Improper use of your report
# 2                                Managing an account
# 3                                      Fraud or scam
# 4            Account opening, closing, or management
# 5                              Getting a credit card
# 6               Incorrect information on your report
# 7               Incorrect information on your report
# 8                     Trouble during payment process
# 9  Problem with a lender or other company chargin...
#
#                                            Sub-issue  \
# 0               Unexpected increase in interest rate
# 1  Credit inquiries on your report that you don't...
# 2                                    Cashing a check
# 3                                               None
# 4                                               None
# 5   Card opened as result of identity theft or fraud
# 6                           Account status incorrect
# 7                           Account status incorrect
# 8                                               None
# 9                     Transaction was not authorized
#
#                         Consumer complaint narrative  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  On XX/XX/20 {$33000.00} was wired from my bank...
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8  Wells Fargo purchased my mortgage from XXXX, s...
# 9  I am writing regarding unauthorized ACH transa...
#
#                              Company public response  \
# 0                                               None
# 1                                               None
# 2  Company has responded to the consumer and the ...
# 3                                               None
# 4                                               None
# 5                                               None
# 6  Company has responded to the consumer and the ...
# 7                                               None
# 8  Company has responded to the consumer and the ...
# 9  Company has responded to the consumer and the ...
#
#                                  Company State ZIP code            Tags  \
# 0                   JPMORGAN CHASE & CO.    FL    32225            None
# 1      CAPITAL ONE FINANCIAL CORPORATION    GA    30082  Older American
# 2  BANK OF AMERICA, NATIONAL ASSOCIATION    MA     1118            None
# 3                   JPMORGAN CHASE & CO.    FL    32137            None
# 4                  WELLS FARGO & COMPANY    TN    37660   Servicemember
# 5      CAPITAL ONE FINANCIAL CORPORATION    FL    32607            None
# 6  BANK OF AMERICA, NATIONAL ASSOCIATION    PA    19405   Servicemember
# 7      CAPITAL ONE FINANCIAL CORPORATION    PA    19380   Servicemember
# 8                  WELLS FARGO & COMPANY    MO    63376            None
# 9  BANK OF AMERICA, NATIONAL ASSOCIATION    PA    152XX            None
#
#   Consumer consent provided? Submitted via Date sent to company  \
# 0       Consent not provided           Web              4/26/18
# 1       Consent not provided           Web              7/18/23
# 2                        NaN      Referral             11/22/17
# 3           Consent provided           Web              1/21/21
# 4                        NaN         Phone              9/29/14
# 5       Consent not provided           Web              8/23/20
# 6       Consent not provided           Web              7/26/22
# 7       Consent not provided           Web              2/14/23
# 8           Consent provided           Web              5/22/19
# 9           Consent provided           Web               5/4/23
#
#       Company response to consumer Timely response? Consumer disputed?  \
# 0          Closed with explanation              Yes                NaN
# 1  Closed with non-monetary relief              Yes                NaN
# 2          Closed with explanation              Yes                NaN
# 3          Closed with explanation              Yes                NaN
# 4          Closed with explanation              Yes                 No
# 5          Closed with explanation              Yes                NaN
# 6          Closed with explanation              Yes                NaN
# 7          Closed with explanation              Yes                NaN
# 8          Closed with explanation              Yes                NaN
# 9          Closed with explanation              Yes                NaN
#
#    Complaint ID
# 0       2887783
# 1       7276310
# 2       2736589
# 3       4082404
# 4       1040743
# 5       3809841
# 6       5809964
# 7       6573129
# 8       3250784
# 9       6930305

# %%
complaints = data.dropna(subset=['Consumer complaint narrative'])

# %%
complaints.isnull().sum()
# Out:
# Date received                        0
# Product                              0
# Sub-product                          0
# Issue                                0
# Sub-issue                            0
# Consumer complaint narrative         0
# Company public response              0
# Company                              0
# State                                0
# ZIP code                             0
# Tags                                 0
# Consumer consent provided?           0
# Submitted via                        0
# Date sent to company                 0
# Company response to consumer         0
# Timely response?                     0
# Consumer disputed?              148723
# Complaint ID                         0
# dtype: int64

# %%
complaints_revised = complaints[['Company', 'Consumer complaint narrative']]

# %%
company_list = ['WELLS FARGO & COMPANY', 'BANK OF AMERICA, NATIONAL ASSOCIATION', 'CAPITAL ONE FINANCIAL CORPORATION', 'JPMORGAN CHASE $ CO.', 'CITIBANK, N.A.']
complaints_revised = complaints_revised[complaints_revised['Company'].isin(company_list)]
complaints_revised.head(10)
# Out:
#                                   Company  \
# 8                   WELLS FARGO & COMPANY
# 9   BANK OF AMERICA, NATIONAL ASSOCIATION
# 10                  WELLS FARGO & COMPANY
# 11  BANK OF AMERICA, NATIONAL ASSOCIATION
# 15      CAPITAL ONE FINANCIAL CORPORATION
# 20                         CITIBANK, N.A.
# 32  BANK OF AMERICA, NATIONAL ASSOCIATION
# 35      CAPITAL ONE FINANCIAL CORPORATION
# 37                         CITIBANK, N.A.
# 39                  WELLS FARGO & COMPANY
#
#                          Consumer complaint narrative
# 8   Wells Fargo purchased my mortgage from XXXX, s...
# 9   I am writing regarding unauthorized ACH transa...
# 10  This happens every time I re-order checks from...
# 11  In XX/XX/2022 I was charged for a hotel room t...
# 15  Capital one/XXXX  XXXX open account XXXX XX/XX...
# 20  XXXX XXXX XXXX XXXX XXXX XXXX, PA XXXX XXXX 15...
# 32  On XXXX 2023 I XXXX XXXX went into the XXXX XX...
# 35  The presence of a derogatory rating on my acco...
# 37  I believe someone cashed a fraudulent check on...
# 39  Called Wells Fargo regarding fraudulent charge...

# %%
import random

# Specify the sample size you want - 50
sample_size = 10

# Extract the 'Consumer complaint narrative' column as a list
narratives = complaints_revised['Consumer complaint narrative'].tolist()

# Check if the number of narratives is greater than the desired sample size
if len(narratives) > sample_size:
    random_samples = random.sample(narratives, sample_size)
else:
    random_samples = narratives

# Create a DataFrame from the sampled narratives
sample = pd.DataFrame({'Consumer complaint narrative': random_samples})

#creating a
sample.to_csv('complaints_generated.csv', index=False)

# %%
sample = sample.dropna(subset=['Consumer complaint narrative'])

# %%
sample.isnull().sum()
# Out:
# Consumer complaint narrative    0
# dtype: int64

# %% [markdown]
# ## Synthesizing Complaints

# %%
random_samples[:5]
# Out:
# ['Capital one auto is in Violation of my consumer rights, they have continually disregarded my disputes of inaccuracies along with not complying to my original dispute but have only stated the account has been verified.. although I have paid off the account in full and it is closed they are still showing late payments that are inaccurate and false this is affecting my consumer report they have had more than enough times to fix this false reporting which is playing a huge part in my credit score fluctuations causing issues with promotions at work and trying to buy a home.. I am extremely exhausted with this situation not having any justification or explanations to me the consumer please delete all PAYMENT that are hurting my report The CFPB states if your account is current and you make an agreement to make a partial payment, skip a payment, or other accommodation, then the creditor is to report to credit reporting companies that you are current on your loan or account. \nIf your account is already delinquent and you make an agreement, then the creditor can not report you as more delinquent ( such as reporting you as 60 days delinquent when you started out 30 days delinquent ) during the period of the agreement. If your account is already delinquent and you make an agreement, and you bring your account current, the creditor must report that you are current on your loan or account. I have the documents proving that I made payment agreements and they still reported late which is a violation of my rights',
#  'On XX/XX/2021, I placed a {$660.00} order on XXXX using my Citi credit card. The website stated that my order would ship out by the end of XXXX, and the return policy stated that customers could cancel and get an 100 % refund if their order was still not shipped 2 weeks after the estimated shipping date. \n\nOn XX/XX/2021, I emailed the XXXX requesting a refund ( in accordance with their Return Policy terms ), but they did not respond ( which is a known tactic they employ according to the customer feedback on their XXXX page ). \n\nOn XX/XX/2021, I opened a dispute with Citi related to the charge, and they issued a provisional credit to my account in the full amount. \n\nOn XX/XX/2021, I received a letter from Citi stating they have " closed our investigation and reversed our credit \'\', and referenced the merchant \'s response ( a " Chargeback Evidence \'\' PDF from Stripe that entirely lacks any information about the Refund Policy or shipment Tracking Number ). \n\nThe letter also stated I could continue the dispute by providing " Proof of the terms and conditions you agreed to and documentation to prove you cancelled in accordance with those terms and conditions. An example of this proof is a cancellation confirmation email from the merchant. \'\' This information was to be emailed to XXXX by XX/XX/2021. \n\nOn XX/XX/2021, I forwarded the order confirmation email & my refund cancellation request email, along with copies of the vendor \'s Refund Policy, and the signed copy of the XX/XX/XXXX letter to XXXX. \n\nOn XX/XX/2021, I received another letter from Citi stating that they are " unable to resolve this dispute in your favor since we have not received the proof of the terms and conditions you agreed to and documentation to prove you cancelled in accordance with those terms and conditions. \'\' I provided all of this information in my XX/XX/2021 email.',
#  "A visa account with citi was open via Costco without my authorization. Further when I attempted to cancel it over two consecutive months a charge was made without my authorization which I was told would be reversed. Over five months into the process, not only it was n't reversed but also interests has been accumulating. This neglect by citi visa will negatively effect my credit score ... Please assist me with the process of correcting it.",
#  "so I have been Wells Fargo for the last couple of weeks to show my loan paid in full it was paid off 3 weeks ago and they refuse to mark it paid in full on the credit bureau I have dealt with a couple of managers and this XXXX XXXX thinks she is god and will not report it until next month I am trying to buy a house and need this balance gone from my credit report. I am upset they will not report this correctly with the credit bureaus and I want this done ASAP this XXXX XXXX is very rude and won't lift a finger to help the credit still shows open and I owe XXXX it should be XXXX i even proof and they sitll won't do it",
#  'To whom it may concernRe : XXXX XXXX XXXX # XXXX XXXX XXXX XXXX XXXX XXXX, XXXX , fl XXXX ( XXXX ) XXXXXXXXAccount # XXXX WellsFargo Bank NAI filed this complain due to a fraud was made in my account on the month of XXXX XXXX, 2015 for the amount of {$5500.00} all this money was withdrawal from my account I was overseas when withdrawals were made in my account without my authorization. I filed a claim with the bank institution which in this case is WellsFargo Bank NA and followed all gave all my supported papers staying that i was not in the country at the time of this transactions. I filed this claim on XXXX XXXX,2015 and this is the claim number with WellsFargo XXXX. I have done XXXX claims and went to the police and no answer just denial that my money was going to refunded to me this is unacceptable they have no answer for me according to them i have my card and is the same card use along with my pin when all this withdrawals made in US and I were in XXXX and denied my claim. I am requesting help to get my money back and answer from this institution that has been playing with me is impossible I could had been XXXX different countries at the same time using my bank card. I would like for you to step on. and maybe they will give you more answer and explanation more then they have evade me with bunch of excuses that not make sense. I am attaching all supported documents that were provided to the bank Institution.']

# %% [markdown]
# ### Equal Complaint Synthesis

# %%
# %%time 

for i in range(len(random_samples[0:5])):
    instructions = [
        {
            "role": "system",
            "content": "Your task is to generate short synthesized customer complaints from banks. \
            Provide modified sample",
        },
        {
            "role": "user",
            "content": f"""
            Generate synthesized complaints by rearranging words and sentence structures while \
            maintaining the same meaning and intensity as the original \
            complaints in at most 50 words. \
            Focus on maintaining equality in the sentiment. 
            
            Complaints: '''{random_samples[i]}'''"""
        }
    ]
    prompt = format_instructions(instructions)
    payload = {
        "inputs": prompt,
        "parameters": {"max_new_tokens": 260, "temperature": 0.5, "top_p": 0.9}
    }
    response = query_endpoint(payload)
    
    print(i, response, "\n")
# Out:
# 0 {'generated_text': " Complaint: '''Capital One Auto is violating my consumer rights by ignoring my disputes of inaccuracies and not complying to my original dispute. They have only stated that the account has been verified, even though I have paid off the account in full and it is closed. They are still showing late payments that are inaccurate and false, which is affecting my credit score fluctuations and causing issues with promotions at work and trying to buy a home. I am exhausted with this situation, and I am extremely frustrated with the lack of justification or explanations. The CFPB states that if your account is current and you make an agreement to make a partial payment, skip a payment, or other accommodation, then the creditor is to report to credit reporting companies that you are current on your loan or account. If your account is already delinquent and you make an agreement, then the creditor can not report you as more delinquent (such as reporting you as 60 days delinquent when you started out 30 days delinquent) during the period of the agreement. If your account is already delinquent and you make an agreement, and you bring your account current"}
#
# 1 {'generated_text': ' On XX/XX/2021, I placed an order for {$660.00} using my Citi credit card. The website stated that my order would ship out by the end of XXXX, and the return policy stated that customers could cancel and get an 100% refund if their order was still not shipped 2 weeks after the estimated shipping date. \n\nOn XX/XX/2021, I emailed the XXXX requesting a refund (in accordance with their Return Policy terms), but they did not respond (which is a known tactic they employ according to the customer feedback on their XXXX page). \n\nOn XX/XX/2021, I opened a dispute with Citi related to the charge, and they issued a provisional credit to my account in the full amount. \n\nOn XX/XX/2021, I received a letter from Citi stating they have "closed our investigation and reversed our credit," and referenced the merchant\'s response (a "Chargeback Evidence" PDF from Stripe that entirely lacks any information about the Refund Policy or shipment Tracking Number). \n\nThe'}
#
# 2 {'generated_text': ' A Citi visa account was opened without my authorization through Costco. When I attempted to cancel it over two consecutive months, a charge was made without my authorization, which I was told would be reversed. After five months, the charge was not reversed, and interest accumulated. This neglect by Citi will negatively impact my credit score. Please assist me with the process of correcting it.'}
#
# 3 {'generated_text': " '''I have been dealing with Wells Fargo for the last couple of weeks to show my loan paid in full. I paid off the loan 3 weeks ago, but they refuse to mark it as paid in full on the credit bureau. I have dealt with a couple of managers, and this XXXX XXXX thinks she is god and will not report it until next month. I need this balance gone from my credit report, and I am upset they won't report it correctly with the credit bureaus. I am trying to buy a house, and this XXXX XXXX is very rude and won't lift a finger to help. The credit still shows open, and I owe XXXX, and it should be XXXX. I have even proof, and they still won't do it.'''"}
#
# 4 {'generated_text': " '''To whom it may concern,\n\nRe: XXXX XXXX XXXX # XXXX XXXX XXXX XXXX XXXX, fl XXXX (XXXX) XXXXXXXX\n\nAccount # XXXX\n\nWellsFargo Bank NAI\n\nFiled this complaint on XXXX XXXX, 2015 due to a fraud made in my account on the month of XXXX XXXX, 2015 for the amount of {$5500.00}.\n\nAll this money was withdrawn from my account without my authorization. I filed a claim with the bank institution, which in this case is WellsFargo Bank NA, and followed all the given papers staying that I was not in the country at the time of these transactions.\n\nI filed this claim on XXXX XXXX, 2015, and this is the claim number with WellsFargo XXXX. I have done XXXX claims and gone to the police, and no answer just denial that my money was going to be refunded to me. This is unacceptable; they have no answer for me. According to them, I have my card and is the same card used along with"}
#
# CPU times: user 92.7 ms, sys: 11.2 ms, total: 104 ms
# Wall time: 33.6 s

# %% [markdown]
# ### Robustness

# %%
# %%time 

for i in range(len(random_samples[0:5])):
    instructions = [
        {
            "role": "system",
            "content": "Your task is to determine if customer complaints from banks are well written without any issues \
            Provide modified sample",
        },
        {
            "role": "user",
            "content": f"""
            Determine if complaints are well-written (considered desirable), \
            exhibit severe grammar or punctuation issues (considered problematic), \
            or contain irrelevant, frivolous information (also considered problematic). \
            Make your response as short as possible
            
            Complaints: '''{random_samples[i]}'''"""
        }
    ]
    prompt = format_instructions(instructions)
    payload = {
        "inputs": prompt,
        "parameters": {"max_new_tokens": 260, "temperature": 0.5, "top_p": 0.9}
    }
    response = query_endpoint(payload)
    
    print(i, response, "\n")
# Out:
# 0 {'generated_text': " The complaint is well-written and exhibits no severe grammar or punctuation issues. It clearly states the customer's concerns and provides specific examples to support their claims. The complaint also provides evidence to support their claims, such as documents proving the customer's agreements with the bank. The customer is also clear in their request for the bank to delete the late payments from their credit report. Overall, the complaint is well-written and exhibits no problematic issues."}
#
# 1 {'generated_text': " The complaint is well-written, but it contains some minor grammar and punctuation issues. The letter is clear and concise, and the writer provides specific examples to illustrate their points. However, the use of all capital letters and the lack of proper punctuation in some sentences may make the text more difficult to read. Additionally, the writer does not provide any specific details about the customer's experience with the bank or the merchant, which could have been helpful in understanding the context of the dispute. Overall, the complaint is well-written, but it could benefit from some minor revisions to improve its clarity and readability."}
#
# 2 {'generated_text': ' The complaint is well-written and contains relevant information. It clearly states the problem and the steps taken to try to resolve it. The use of proper grammar and punctuation is also evident. The only issue is the use of contractions, which may be seen as a minor flaw. However, it does not detract from the overall quality of the complaint.'}
#
# 3 {'generated_text': ' The complaint is well-written and contains relevant information about the customer\'s experience with Wells Fargo. However, there are some grammatical errors and punctuation issues that could be improved.\n\nHere\'s a modified version of the complaint with suggested corrections:\n\n"I have been a customer of Wells Fargo for the last couple of weeks. I have paid off my loan in full three weeks ago, and yet they refuse to mark it as paid in full on the credit bureau. I have dealt with several managers, and this XXXX XXXX thinks she is god and will not report it until next month. I am trying to buy a house and need this balance gone from my credit report. I am upset that they will not report this correctly with the credit bureaus and I want this done ASAP. This XXXX XXXX is very rude and won\'t lift a finger to help. The credit still shows open, and I owe XXXX, but they still won\'t do it."\n\nIn this modified version, I have corrected the following grammatical errors:\n\n* "so I have been Wells Fargo" should be "I have been a customer of Wells'}
#
# 4 {'generated_text': ' The complaint is well-written and contains all the necessary information to make a claim. It is clear and concise, and the author has provided all the necessary details to support their claim. The grammar and punctuation are good, and there are no obvious errors. The only issue is that the tone is a bit confrontational, which may not be the most effective way to approach the bank. However, overall, the complaint is well-written and can be used to make a claim.'}
#
# CPU times: user 99.6 ms, sys: 3.46 ms, total: 103 ms
# Wall time: 22.1 s

# %% [markdown]
# ### Invariance

# %%
# %%time 

for i in range(len(random_samples[0:5])):
    instructions = [
        {
            "role": "system",
            "content": "Your task is to generate short synthesized customer complaints from banks. \
            Provide modified samples",
        },
        {
            "role": "user",
            "content": f"""
            Create synthetic complaints that retain the core message \
            and sentiment of the original complaints but change some words \
            or phrases while ensuring there is no change in the overall meaning \
            in at most 50 words 
            
            Complaints: '''{random_samples[i]}'''"""
        }
    ]
    prompt = format_instructions(instructions)
    payload = {
        "inputs": prompt,
        "parameters": {"max_new_tokens": 260, "temperature": 0.5, "top_p": 0.9}
    }
    response = query_endpoint(payload)
    
    print(i, response, "\n")
# Out:
# 0 {'generated_text': " '''Capital One Auto is in Violation of my Consumer Rights. They have repeatedly ignored my disputes of inaccuracies and failed to comply with my original dispute, stating that the account has been verified despite my payment of the account in full and it being closed. Despite this, they are still reporting late payments that are inaccurate and false, which is affecting my consumer report and causing fluctuations in my credit score. I am extremely frustrated with this situation and am seeking resolution. The CFPB states that if an account is current and you make an agreement to make a partial payment, skip a payment, or other accommodation, then the creditor must report to credit reporting companies that you are current on your loan or account. If an account is already delinquent and you make an agreement, then the creditor can not report you as more delinquent (such as reporting you as 60 days delinquent when you started out 30 days delinquent) during the period of the agreement. If an account is already delinquent and you make an agreement, and you bring your account current, the creditor must report that you are current on your loan or account. I have the documents proving"}
#
# 1 {'generated_text': ' On XX/XX/2021, I placed a {$660.00} order on XXXX using my Citi credit card. The website stated that my order would ship out by the end of XXXX, and the return policy stated that customers could cancel and get an 100 % refund if their order was still not shipped 2 weeks after the estimated shipping date. \n\nOn XX/XX/2021, I emailed the XXXX requesting a refund ( in accordance with their Return Policy terms ), but they did not respond ( which is a known tactic they employ according to the customer feedback on their XXXX page ). \n\nOn XX/XX/2021, I opened a dispute with Citi related to the charge, and they issued a provisional credit to my account in the full amount. \n\nOn XX/XX/2021, I received a letter from Citi stating they have " closed our investigation and reversed our credit \'\', and referenced the merchant \'s response ( a " Chargeback Evidence \'\' PDF from Stripe that entirely lacks any information about the Refund Policy or shipment Tracking Number ). \n'}
#
# 2 {'generated_text': ' Sure, here are five modified synthetic complaints that retain the core message and sentiment of the original complaint but change some words or phrases while ensuring there is no change in the overall meaning in at most 50 words:\n\n1. "I had a Visa account with Citi that was opened without my knowledge or consent. When I tried to cancel it, I was charged without my authorization, and I was told the charge would be reversed. It\'s been over five months, and the charge hasn\'t been reversed, and interest has accumulated. This negligence by Citi is affecting my credit score ... Please help me resolve this issue."\n2. "I had a Visa account with Citi that was opened without my permission. When I tried to close it, I was charged without my knowledge, and I was told the charge would be reversed. It\'s been over five months, and the charge hasn\'t been reversed, and interest has accumulated. This incompetence by Citi is damaging my credit score ... Please assist me in resolving this problem."\n3. "I had a Visa account with Citi that was opened without my consent. When I tried to cancel it'}
#
# 3 {'generated_text': ' Here are five modified versions of the original complaint, each with at most 50 words:\n\n1. "I\'ve been trying to get my loan paid off for weeks, but Wells Fargo is refusing to report it as paid in full. I\'ve dealt with several managers and this XXXX is being uncooperative and unprofessional. I need this balance gone from my credit report, and I\'m upset that they\'re not taking action to fix the issue."\n2. "I paid off my loan 3 weeks ago, but Wells Fargo is still showing it as open on my credit report. I\'ve tried to resolve this with several managers, but this XXXX is being unresponsive and unhelpful. I need this issue resolved as soon as possible, and I\'m frustrated that they\'re not taking action to fix it."\n3. "I\'m trying to buy a house, and this XXXX at Wells Fargo is being uncooperative and unprofessional. They\'re refusing to report my loan as paid in full, and it\'s holding me back from getting a good credit score. I need this issue resolved as soon as'}
#
# 4 {'generated_text': " '''To whom it may concern,\n\nRe: XXXX XXXX XXXX # XXXX XXXX XXXX XXXX XXXX, WellsFargo Bank NAI\n\nI am writing to express my frustration with the fraudulent activity that took place on my account on the month of XXXX XXXX, 2015. The amount of {$5500.00} was withdrawn from my account without my authorization, and I was overseas at the time of these transactions. I filed a claim with WellsFargo Bank NA and provided all the necessary documents to support my claim. However, I have not received any response from the bank institution, and I am still waiting for a resolution to this matter.\n\nI have tried to reach out to the bank institution multiple times, but I have not received any answer or explanation for why my money was not refunded. I am requesting help to get my money back and an explanation from the bank institution. I have attached all the supporting documents that I provided to the bank institution.\n\nI am very disappointed with the lack of response from the bank institution and the fact that they are not taking this matter seriously. I would appreciate any help or assistance"}
#
# CPU times: user 82.9 ms, sys: 15.9 ms, total: 98.8 ms
# Wall time: 41.9 s

# %% [markdown]
# ### Harshness

# %%
# %%time 

for i in range(len(random_samples[0:5])):
    instructions = [
        {
            "role": "system",
            "content": "Your task is to generate short synthesized customer complaints from banks. \
            Provide modified samples",
        },
        {
            "role": "user",
            "content": f"""
            Develop a method to make complaints more harsh or less harsh \
            while keeping the underlying issue intact in at most 50 words\
            Use a range of intensity levels (Less Harsh or More harsh)) to ensure diversity 
            
            Complaints: '''{random_samples[i]}'''"""
        }
    ]
    prompt = format_instructions(instructions)
    payload = {
        "inputs": prompt,
        "parameters": {"max_new_tokens": 260, "temperature": 0.5, "top_p": 0.9}
    }
    response = query_endpoint(payload)
    
    print(i, response, "\n")
# Out:
# 0 {'generated_text': ' Here are five modified customer complaints with different levels of harshness:\n\n1. Less harsh:\n\n"I\'m frustrated with Capital One Auto because they\'ve ignored my disputes and failed to correct inaccuracies on my account. Despite making payments, they\'re still reporting late payments that are false and harming my credit score. I\'ve tried to resolve the issue multiple times, but they\'ve failed to address it. I\'m very disappointed and hope they take action to fix the problem."\n\n2. Moderately harsh:\n\n"I\'m fed up with Capital One Auto. They\'ve consistently ignored my disputes and failed to correct inaccuracies on my account, even after I\'ve made payments. Despite bringing the account current, they\'re still reporting late payments that are false and harming my credit score. I\'ve tried to resolve the issue multiple times, but they\'ve failed to address it. I\'m extremely frustrated and hope they take action to fix the problem."\n\n3. More harsh:\n\n"I\'m outraged with Capital One Auto. They\'ve consistently ignored my disputes'}
#
# 1 {'generated_text': ' Complaints: \'\'\'On XX/XX/2021, I placed a {$660.00} order on XXXX using my Citi credit card. The website stated that my order would ship out by the end of XXXX, and the return policy stated that customers could cancel and get an 100 % refund if their order was still not shipped 2 weeks after the estimated shipping date. \n\nOn XX/XX/2021, I emailed the XXXX requesting a refund ( in accordance with their Return Policy terms ), but they did not respond ( which is a known tactic they employ according to the customer feedback on their XXXX page ). \n\nOn XX/XX/2021, I opened a dispute with Citi related to the charge, and they issued a provisional credit to my account in the full amount. \n\nOn XX/XX/2021, I received a letter from Citi stating they have " closed our investigation and reversed our credit \'\', and referenced the merchant \'s response ( a " Chargeback Evidence \'\' PDF from Stripe that entirely lacks any information about the Refund Policy or shipment Track'}
#
# 2 {'generated_text': ' Here are five modified customer complaints with different levels of harshness while keeping the underlying issue intact:\n\n1. "Citi Visa: Unauthorized Charge and No Reversal. This is a scam!"\n2. "Citi Visa: Unauthorized Charge and No Reversal. This is a disaster for my credit score!"\n3. "Citi Visa: Unauthorized Charge and No Reversal. I can\'t believe I was taken advantage of by this bank!"\n4. "Citi Visa: Unauthorized Charge and No Reversal. This is a clear violation of my rights as a customer!"\n5. "Citi Visa: Unauthorized Charge and No Reversal. I demand a full refund and an apology for this unacceptable situation!"'}
#
# 3 {'generated_text': ' Complaint 1 (Less Harsh):\n\n"I\'ve been a customer of Wells Fargo for over a month, and I\'ve been trying to get my loan paid off. Despite my repeated requests, the credit bureau still shows my loan as open. I\'ve dealt with several managers, but they refuse to mark my loan as paid in full. I\'m upset and frustrated with their lack of action. I need this issue resolved as soon as possible."\n\nComplaint 2 (More Harsh):\n\n"I can\'t believe I\'ve been a customer of Wells Fargo for over a year, and I still haven\'t been able to get my loan paid off. Despite my repeated requests, the credit bureau still shows my loan as open. I\'ve dealt with multiple managers, but they\'re all incompetent and refuse to take action. I\'m fed up with their lack of responsibility and need this issue resolved immediately. I\'m going to have to take legal action if I don\'t get this resolved."\n\nComplaint 3 (Most Harsh):\n\n"I\'ve been a customer of Wells F'}
#
# 4 {'generated_text': " Complaint 1:\n\nTo whom it may concern,\n\nI am writing to express my dissatisfaction with the fraudulent activity that occurred in my WellsFargo Bank account. On the month of XXXX XXXX, 2015, I discovered that $5500.00 was withdrawn from my account without my authorization. This happened while I was overseas, and I have provided all the necessary documents to support my claim. Despite my efforts, the bank has refused to provide any explanation or refund. I am requesting your assistance in resolving this matter and getting my money back.\n\nComplaint 2:\n\nDear Sir/Madam,\n\nI am writing to express my extreme dissatisfaction with the WellsFargo Bank's handling of my account. On the month of XXXX XXXX, 2015, I discovered that $5500.00 was withdrawn from my account without my authorization. This happened while I was overseas, and I have provided all the necessary documents to support my claim. Despite my efforts, the bank has refused to provide any explanation or refund. I am requesting your immediate attention"}
#
# CPU times: user 92.8 ms, sys: 1.22 ms, total: 94.1 ms
# Wall time: 39.5 s

# %% [markdown]
# ## More Harsh Complaints (for Evaluation)

# %%
#generated 1
# %%time 

for i in range(len(random_samples[0:10])):
    instructions = [
        {
            "role": "system",
            "content": "Your task is to generate short synthesized customer complaints from banks. \
            Provide modified samples",
        },
        {
            "role": "user",
            "content": f"""
            Develop a method to make complaints more harsh \
            while keeping the underlying issue intact in at most 50 words\
            
            Complaints: '''{random_samples[i]}'''"""
        }
    ]
    prompt = format_instructions(instructions)
    payload = {
        "inputs": prompt,
        "parameters": {"max_length": 50, "max_new_tokens": 260, "temperature": 0.8, "top_p": 0.9}
    }
    response = query_endpoint(payload)
    
    print(i+1, response, "\n")
# Out:
# 1 {'generated_text': ' "Capital One Auto is a total disaster! They have consistently ignored my disputes of inaccuracies, failed to comply with my original disputes, and have only stated that my account has been verified even though I have paid off the account in full and it\'s closed. They\'re still showing late payments that are inaccurate and false, which is causing me a huge problem with my credit score fluctuations. They\'re also playing a huge part in my credit score fluctuations. I\'m so frustrated with the CFPB, it states if your account is current and you make an agreement to make a partial payment, skip a payment, or other accommodation, then the creditor is to report to credit reporting companies that you are current on your loan or account. If your account is already delinquent and you make an agreement, then the creditor can not report you as more delinquent (such as reporting you as 60 days delinquent when you started out 30 days delinquent) during the period of the agreement. If your account is already delinquent and you make an agreement, and you bring your account current, the creditor must report that you are'}
#
# 2 {'generated_text': ' On XX/XX/2021, I placed a $660.00 order on XXXX using my Citi credit card. The website stated that my order would ship out by the end of XXXX, and the return policy stated that customers could cancel and get an 100% refund if their order was still not shipped 2 weeks after the estimated shipping date.\n\nOn XX/XX/2021, I emailed the XXXX requesting a refund, but they did not respond, which is a known tactic they employ according to the customer feedback on their XXXX page.\n\nOn XX/XX/2021, I opened a dispute with Citi related to the charge, and they issued a provisional credit to my account in the full amount.\n\nOn XX/XX/2021, I received a letter from Citi stating they have " closed our investigation and reversed our credit," and referenced the merchant\'s response (a "Chargeback Evidence" PDF from Stripe that entirely lacks any information about the Refund Policy or shipment tracking number).\n\nThe letter also stated that I could continue the dispute by providing "proof'}
#
# 3 {'generated_text': " '''The security of my Costco credit card was compromised by Citi without my knowledge. When I attempted to cancel the card over two consecutive months, I was charged without my permission, and it wasn't reversed. Citi's neglect and lack of action will negatively impact my credit score. Please assist me in resolving this issue.'''\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"}
#
# 4 {'generated_text': ' Here are five synthesized customer complaints about banks, with the underlying issue intact in at most 50 words:\n\n1. "I have been a Wells Fargo customer for over a year, and have always paid my bills on time. However, I recently received a call from a representative stating that I owed a large amount of money on my account, despite my previous payments being made. I have dealt with multiple managers, and each one has made the same claim, despite the fact that my payments have been made on time. I am extremely frustrated with the bank\'s lack of communication and customer service, and am considering switching to another bank."\n2. "I have been a Chase customer for several years, and have always been satisfied with their service. However, I recently had a problem with a loan I took out with the bank. Despite my repeated requests for help, the representative on the other end of the phone refused to assist me, and instead told me that I would have to take my issue to a supervisor. I waited for several days, but was never contacted by a supervisor, and my loan has been sitting at the top of my account for months. I am very disappointed with'}
#
# 5 {'generated_text': ' Dear WellsFargo Bank NA,\n\nI am writing to express my extreme dissatisfaction with the fraudulent activity that took place on my account on the month of XXXX XXXX, 2015. I was overseas when the withdrawals were made from my account without my authorization, resulting in the loss of {$5500.00}. I have followed all of the proper channels to file a claim with your institution, but no answer or explanation has been provided.\n\nI have been unsuccessful in getting my money back and have been met with denials and excuses that do not make sense. I have also gone to the police and they have denied my claim. I am requesting your immediate attention to this matter and a full explanation of what happened and what steps you are taking to rectify the situation.\n\nI am attaching all of the supporting documents that were provided to your institution, including my card and pin number, which I used to make the withdrawals in question. I am hoping that you will take this matter seriously and provide me with a satisfactory explanation and solution.\n\nSincerely,\n[Your Name]'}
#
# 6 {'generated_text': ' "I can\'t believe my account was closed for no reason. I had two checks deposited and the next day my account was frozen and closed for cause. I had to call the check issuer and have them re-issued. Wells Fargo reported to the FTC that my savings account and checking account were closed for cause. This is unacceptable. Banks should not close accounts so quickly and without a valid reason. It\'s causing me a lot of inconvenience and stress."'}
#
# 7 {'generated_text': ' Complaint:\n\nOn XXXX XXXX 2016, I visited the Wells Fargo branch located at XXXX XXXX XXXX , XXXX, TX XXXX to deposit a check and cash. However, upon my arrival, the teller informed me that the check I brought had not been registered in my account. I had already spoken to the branch manager and was told that the chances of the employee stealing the cash were higher than the chances of them just taking the check. I was told that I would need to find the check number from the USPS and call back to stop payment.\n\nI had already called the branch and spoken to the Assistant Manager, who had confirmed that no such check had been deposited. I had requested to see the video tape to prove that I had been there, but the manager refused and hung up abruptly.\n\nI am extremely disappointed in the service I received at the Wells Fargo branch and am extremely frustrated with the lack of communication and follow-up from the bank. I will never be able to access my cash and I am extremely concerned about the security of my account. I demand a full refund for the amount I brought'}
#
# 8 {'generated_text': ' Dear WellsFargo,\n\nI am writing to express my extreme dissatisfaction with the recent actions taken against my account. On the evening of XX/XX/2019, you withdrew {$390.00} from my checking and {$560.00} from my savings account, without any prior notice or explanation. This is unacceptable and shows a complete disregard for my well-being and financial security.\n\nThe reason for the charges is not important to me, as I have already spoken to your customer service representatives and they were not helpful in addressing my concerns. However, what is important is that you took this amount of money from my account without my permission and without any explanation or apology. This is unethical and unacceptable behavior, and I demand that you take immediate action to rectify the situation.\n\nFurthermore, I have received one letter in the last year from the law group that you are using to try and sue me for a total amount of {$190.00}. While I understand that I owe the amount on the credit card and that payment arrangements need to be made, this is not a suitable solution for the'}
#
# 9 {'generated_text': ' "Capital One\'s inaction in removing the 30 day late from my credit report caused a permanent damage to my FICO score, preventing me from refinancing my home. The 2 month deferral approved for COVID-19 was invalidated by Capital One\'s inaction. I have never been late on any of my credit cards and have always been a responsible borrower. Please take immediate action to address this issue and restore my credit score."'}
#
# 10 {'generated_text': " '''My name is XXXX XXXX this complaint is not made in error neither is it being made by a third party. I declare under penalty of perjury I am alleging that a person or company- without my authorization- from unauthorized use of my social security number and card used my personal identifying information to apply for goods, services, or money ; and, was successful in creating some accounts. I have no knowledge of this and all is being investigated by the FTC and Under 15 U.S. Code 1681b Permissible purposes of consumer reports I never gave any written consent to report anything on my consumer reportsno consent is fraud. WF/XXXX  XXXX Date Open : XX/XX/XXXX Balance : {$24000.00} and WELLS FARGO XXXX Date Open : XX/XX/XXXX Balance : {$1800.00}.'''\n\nThis complaint was not made in error or by a third party. It is alleging that a person or company, without authorization, used the social security number and card to apply for goods, services, or money; and, were successful in creating some accounts. The person"}
#
# CPU times: user 265 ms, sys: 11.6 ms, total: 277 ms
# Wall time: 1min 14s

# %%
# %%time 

for i in range(len(random_samples[0:10])):
    instructions = [
        {
            "role": "system",
            "content": "Your task is to generate short synthesized customer complaints from banks. \
            Provide modified samples",
        },
        {
            "role": "user",
            "content": f"""
            Develop a method to make complaints more harsh \
            while keeping the underlying issue intact in at most 50 words. 
            Make sure all sentences are complete.
            
            Complaints: '''{random_samples[i]}'''"""
        }
    ]
    prompt = format_instructions(instructions)
    payload = {
        "inputs": prompt,
        "parameters": {"max_length": 50, "max_new_tokens": 260, "temperature": 0.8, "top_p": 0.9}
    }
    response = query_endpoint(payload)
    
    print(i+1, response, "\n")
# Out:
# 1 {'generated_text': ' "Capital One Auto is in clear violation of my consumer rights by ignoring my disputes of inaccuracies and not complying with my original dispute. Despite paying off the account in full, they are still showing late payments that are false and inaccurate. This is affecting my credit score, causing problems with promotions at work and trying to buy a home. I am extremely frustrated with this situation and am exhausted with their lack of justification or explanations. I have the documents proving that I made payment agreements, but they still reported late payments. The CFPB states that if your account is current and you make an agreement to make a partial payment, skip a payment, or other accommodation, then the creditor is to report to credit reporting companies that you are current on your loan or account. If your account is already delinquent and you make an agreement, then the creditor can not report you as more delinquent (such as reporting you as 60 days delinquent when you started out 30 days delinquent) during the period of the agreement. If your account is already delinquent and you make an agreement, and you bring your account current, the cred'}
#
# 2 {'generated_text': ' On 03/23/2022, I placed a $660.00 order on XXXXX using my Citi credit card. The website stated that my order would ship out by the end of March, and the return policy stated that customers could cancel and get an 100% refund if their order was still not shipped 2 weeks after the estimated shipping date. \n\nOn 03/23/2022, I emailed the XXXXX requesting a refund ( in accordance with their Return Policy terms ), but they did not respond ( which is a known tactic they employ according to the customer feedback on their XXXXX page ). \n\nOn 03/23/2022, I opened a dispute with Citi related to the charge, and they issued a provisional credit to my account in the full amount. \n\nOn 03/23/2022, I received a letter from Citi stating they have " closed our investigation and reversed our credit \'\', and referenced the merchant \'s response ( a " Chargeback Evidence \'\' PDF from Stripe that entirely lacks any information about the Refund'}
#
# 3 {'generated_text': ' Visa account opened by Costco without authorization. Cancellation charges not reversed after two months. Interest accumulated. Neglect by Citi Visa impacting credit score. Please assist with correcting.'}
#
# 4 {'generated_text': " Complaints:\n\n* I have been a Wells Fargo customer for over a month, and despite showing my loan as fully paid, the credit bureau still lists it as open. I have dealt with multiple managers, and the one who is currently handling my account is not helpful at all. She thinks she's the CEO of the company and is not willing to report my loan as paid until next month. This is causing a problem for me when trying to buy a house, as the loan balance still shows on my credit report.\n* I have been a Wells Fargo customer for several years and have always been satisfied with the service I receive. However, this recent experience has been a nightmare. Despite showing my loan as fully paid, the credit bureau still lists it as open. I have tried to work with multiple managers, but the one I am currently dealing with is unhelpful and uncooperative. She thinks she's the CEO of the company and is not willing to report my loan as paid until next month. This is causing a problem for me when trying to buy a house, as the loan balance still shows on my credit report.\n* I have been a Wells Fargo customer for over"}
#
# 5 {'generated_text': ' Dear Sir/Madam,\n\nI am writing to express my extreme dissatisfaction with the actions of your bank, WellsFargo Bank NAI. I had opened a savings account with your institution in the month of XXXX XXXX, 2015, and unfortunately, I have been subjected to fraudulent transactions in my account.\n\nOn the month of XXXX XXXX, 2015, I noticed that an unknown entity had withdrawn a total of {$5500.00} from my account without my authorization. This was a clear violation of my rights as a customer, as I was not in the country at the time of the withdrawals. I filed a claim with your institution and provided all the necessary documents to support my claim.\n\nDespite my efforts, I have been met with silence and a lack of resolution. I have been told that my claim is being investigated and that I will receive a refund for the amount withdrawn, but no update has been provided. It has been over six months since the incident, and I am still waiting for any form of resolution.\n\nI am extremely frustrated with the lack of communication and support from'}
#
# 6 {'generated_text': " '''My account was closed due to an oversight. I deposited two third party checks and the next day my account was frozen and closed due to an oversight. I ended up having to call the check issuer and have both checks re-issued. Wells Fargo has reported to XXXX that both my savings account and checking account were closed due to an oversight which has caused me to be unable to open a bank account. The banks are too quick to close for suspected fraud without thoroughly investigating which is causing many consumers unnecessary inability to open a bank account.'''"}
#
# 7 {'generated_text': ' "I visited the Wells Fargo branch at XXXX XXXX 2016 to deposit a check and cash. The banker at the teller line asked for my debit card, but he did n\'t deposit the check or cash into my account. When I asked to exchange some coins I had brought from home, he counted them with a plastic device and gave me some change. I found out that neither the check I deposited nor the cash I deposited had been registered in my account. I called the branch manager and spoke to the Assistant Manager. I was refused access to the video tape to prove I was at the branch, and he refused to stop payment on the check. I was left feeling frustrated and disappointed with the bank\'s customer service."'}
#
# 8 {'generated_text': " '''\nOn Friday XX/XX/2019, I discovered that my WellsFargo account was drained of $390.00 from my checking and $560.00 from my savings without my knowledge or consent. When I tried to contact WellsFargo to inquire about the charges, the customer service representative was unhelpful and unkind. She did not offer much insight into the charges, only that they were related to a closed credit card. However, she was unable to provide me with any information about the charges or the account itself.\n\nI have noticed several inconsistencies with my account, including the fact that this credit card does not appear on my account, and that I do not have any access to the account or any information about the charges. Additionally, my account has been listed as a write-off on my credit report.\n\nI have also received one letter from a law firm that WellsFargo is using to try and sue me for a total amount of $190.00. I have communicated with the firm, and they have confirmed that I am eligible for a settlement. However, I am still waiting to receive the letter and have not yet seen any information"}
#
# 9 {'generated_text': " This complaint shows that the customer requested a forbearance or payment deferral due to the COVID-19 pandemic and was approved for a 2-month deferral, but was later shown as 30 days late on their credit report, which resulted in a lowering of their FICO score. The customer contacted Capital One and was refused to remove the 30-day late, despite having never been late on their credit cards. The customer had also been refinancing their home, but the FICO score lowering made them ineligible to complete the refinance loan. This complaint highlights how the customer's COVID-19-related request was ignored and their credit score was negatively impacted."}
#
# 10 {'generated_text': ' I am writing to express my extreme dissatisfaction with the unauthorized use of my social security number and credit card information. I have no idea how this happened, but I have received multiple accounts in my name without my consent. I am deeply disturbed by this violation of my privacy and trust, and I am seeking compensation for the financial loss I have incurred.\n\nI am also outraged by the fact that my personal information was used to create fake accounts without my knowledge or consent. This is a clear violation of my rights as a consumer, and I demand that the FTC take immediate action to protect me from such unethical and illegal practices.\n\nI have reviewed the 15 U.S. Code section 1681b, and I am aware that consumer reports are not considered consent, and this behavior is considered fraud. I am seeking legal action against the perpetrators of this fraud and am requesting a full refund of the funds that were stolen from me.\n\nI demand that Wells Fargo take immediate action to rectify this situation and ensure that my personal information is kept confidential and secure. I expect a prompt response to this complaint and am willing to'}
#
# CPU times: user 176 ms, sys: 17 ms, total: 193 ms
# Wall time: 1min 7s

# %%
# %%time 

for i in range(len(random_samples[0:10])):
    instructions = [
        {
            "role": "system",
            "content": "Your task is to generate short synthesized customer complaints from banks. \
            Provide modified samples",
        },
        {
            "role": "user",
            "content": f"""
            Develop a method to make complaints more harsh \
            while keeping the underlying issue intact in at most 50 words. 
            Make sure all sentences are complete.
            
            Complaints: '''{random_samples[i]}'''"""
        }
    ]
    prompt = format_instructions(instructions)
    payload = {
        "inputs": prompt,
        "parameters": {"max_length": 50, "max_new_tokens": 260, "temperature": 0.8, "top_p": 0.9}
    }
    response = query_endpoint(payload)
    
    print(i+1, response, "\n")
# Out:
# 1 {'generated_text': ' Complaint:\n\n"Bank of America is consistently failing to honor my dispute resolution agreements. Despite my repeated efforts to resolve disputes with inaccurate information, they have repeatedly ignored my requests and reported false late payments. This has had a significant impact on my credit score and my ability to obtain loans and credit. I have provided evidence of my agreements and the false late payments, but the bank has refused to take action. I am extremely frustrated with their lack of commitment to customer satisfaction and their failure to uphold their obligations. I demand that they take immediate action to address this issue and provide me with a satisfactory resolution."'}
#
# 2 {'generated_text': ' Customer Complaint:\n\nDear Citi,\n\nI am writing to express my frustration with the way my credit card charge was handled. I placed an order on your platform using my credit card, and the website stated that the order would ship out by the end of the month. However, the return policy stated that customers could cancel and get a full refund if their order was still not shipped 2 weeks after the estimated shipping date.\n\nOn the 20th of this month, I emailed your customer service team requesting a refund, but I did not receive a response. I was shocked and frustrated when I received a letter from you stating that you had "closed our investigation and reversed our credit." The letter also referenced a "Chargeback Evidence" PDF from Stripe that lacked any information about the refund policy or shipment tracking number.\n\nI was not satisfied with the lack of communication from your team and the lack of information provided in the letter. I also received a second letter stating that they are unable to resolve the dispute in my favor because they have not received the proof of the terms and conditions I agreed to and documentation to prove that I cancelled in accordance with'}
#
# 3 {'generated_text': " Complaint: '''I was a victim of a fraudulent visa account opened by Citi through Costco without my authorization. After attempting to cancel it twice, I was charged without my knowledge, which I was assured would be reversed. But it wasn't. The fraud was left uncorrected for over five months, with accumulating interest. This negatively impacted my credit score. I am seeking assistance to fix this issue.'''\n\nComplaint: '''I had a Citi visa account opened through Costco without my consent. Despite my repeated attempts to cancel it, a fraudulent charge was made. It took over five months to reverse the charge, with interest accumulating. This has negatively impacted my credit score. I need assistance to resolve this issue.'''\n\nComplaint: '''I was a victim of a Citi visa fraud opened through Costco without my knowledge. Attempting to cancel it twice resulted in a charge without my approval. The fraud was uncorrected for over five months, with interest accumulating. This has damaged my credit score. I need assistance to fix this issue.'''\n\nComplaint: '''I had a Citi visa"}
#
# 4 {'generated_text': " Complaints: '''I have been a customer of Wells Fargo for years, and I recently had a terrible experience with one of their managers. I had a loan that I paid off in full 3 weeks ago, but the credit bureau still shows it as still open. I have dealt with multiple managers and this XXXX XXXX is the most unhelpful. She is condescending and rude, and won't even look into this issue until next month. I need this balance gone from my credit report as soon as possible. I am upset and frustrated with the lack of assistance from Wells Fargo. I need this resolved as soon as possible.'''"}
#
# 5 {'generated_text': ' Here is a modified version of the customer complaint, with a harsher tone while still maintaining the underlying issue:\n\n"WellsFargo Bank NAI, you\'re scum! You\'ve been playing a game with me for months, stealing my hard-earned money and denying my claims. I\'ve been a loyal customer for years, and this is how you repay me? By ripping me off and making me look like a fool in front of the police? I\'m done with you and your bank. I\'m filing a lawsuit and taking you down with me. You\'re not only stealing from me, you\'re stealing from the bank. You\'re a joke, a scam, and I\'ll never be back. Get ready to lose more money and face the consequences of your actions. This is the end of an era, WellsFargo."'}
#
# 6 {'generated_text': ' Here are five modified customer complaints with a harsher tone:\n\n1. "You closed my account without even giving me a chance to explain myself! I was trying to open a new account and you decided to close mine without any reason. I had to deal with the inconvenience of having to re-issue two checks and then having to call the check issuer to get my money back. This is unacceptable and I will never do business with Wells Fargo again."\n2. "I can\'t believe you guys closed my account for no reason! I\'ve been a customer for years and I never had any problems. But then I tried to open a new account and you decided to close my old one without any explanation. I had to deal with the hassle of having to re-issue two checks and then having to call the check issuer to get my money back. This is just ridiculous and I will never do business with Wells Fargo again."\n3. "I can\'t believe you guys are so quick to close accounts for no reason! I had a good balance in my account and then I tried to open a new one and you decided to close my old one without any explanation. I had to deal'}
#
# 7 {'generated_text': ' Dear [Bank Name],\n\nI am writing to express my frustration with the service I received at your [Location] branch on [Date]. I went to deposit a check and cash, but the bank representative told me that the transaction was not recorded in my account. I confirmed with the branch manager, who confirmed that the check was not deposited in my account.\n\nI was shocked and disappointed by the lack of communication and attention to detail from your staff. I had to go to a different branch to make a deposit, which caused me to waste a lot of time. The inconvenience and frustration I experienced during my visit was not worth the lack of service I received.\n\nI demand a refund for the cash I deposited and a resolution to this issue. I also expect a formal apology for the inconvenience and frustration I experienced during my visit.\n\nSincerely,\n[Your Name]'}
#
# 8 {'generated_text': ' Dear WellsFargo,\n\nI am writing to express my dissatisfaction with the recent withdrawal of funds from my checking and savings accounts. On Friday, XX/XX/2019, I was notified that {$390.00} had been taken from my checking account and {$560.00} had been taken from my savings account. When I called WellsFargo to discuss the charges, the customer service representative was polite but unhelpful. She could not provide me with much information about the charges except that it was for a closed credit card.\n\nHowever, this credit card does not appear on my account, and there is no way for me to track how much is owed, payments made, or anything related to this account. I do not receive any paperwork, statements, or access to this account. This account is on my credit report as a write-off, and it has been for several years.\n\nFurthermore, this account is old, and I do not have the card number anymore. When I have called in the past, WellsFargo employees could not find any information on the account. I have recieved one letter in the last year from'}
#
# 9 {'generated_text': ' Complaint: \n\nI am extremely disappointed with the way Capital One treated my credit report. \n\nI requested a deferral on my payments due to COVID-19 in XXXX, 2020. I was approved for a 2 month deferral and received the deferral letter on XXXX, 2020. \n\nHowever, Capital One did not remove the 30 day late from my credit report. \n\nThis resulted in a 30 day late showing up on my credit report and a FICO score lowering of XXXX points. I had requested the same with 8 other credit card companies and was approved with all. \n\nI contacted Capital One by phone and letter but they refused to remove the 30 day late. I have never been 30 days late on any of my credit cards, and I am currently in the process of refinancing my home. \n\nThe FICO score lowering made me " NOT ELIGIBLE " to complete the refinance loan. \n\nI have been with Capital One for 10 years and have never been late. This is unacceptable and I am disappoint'}
#
# 10 {'generated_text': ' Sure, here\'s a modified version of the complaint that\'s more harsh while keeping the underlying issue intact:\n\n"I am outraged that Wells Fargo has been using my personal information without my consent to apply for goods, services, and money. I have no idea how this happened, and it\'s all being investigated by the FTC. I never gave any written consent to report anything on my consumer reports, and this is a clear case of fraud. My social security number and card were used to create fake accounts, and I have no knowledge of this. I demand that Wells Fargo takes immediate action to rectify this situation and protect my personal information. This is unacceptable, and I will not stand for it."'}
#
# CPU times: user 184 ms, sys: 12.7 ms, total: 196 ms
# Wall time: 1min 9s

# %%
# %%time 

for i in range(len(random_samples[0:10])):
    instructions = [
        {
            "role": "system",
            "content": "Your task is to generate short synthesized customer complaints from banks. \
            Provide modified samples",
        },
        {
            "role": "user",
            "content": f"""
            Develop a method to make complaints more harsh \
            while keeping the underlying issue intact in at most 50 words. 
            Make sure all sentences are complete.
            
            Complaints: '''{random_samples[i]}'''"""
        }
    ]
    prompt = format_instructions(instructions)
    payload = {
        "inputs": prompt,
        "parameters": {"max_length": 50, "max_new_tokens": 260, "temperature": 0.8, "top_p": 0.9}
    }
    response = query_endpoint(payload)
    
    print(i+1, response, "\n")
# Out:
# 1 {'generated_text': " '''Capital One Auto is in complete violation of my consumer rights! They have consistently disregarded my disputes over inaccuracies and not complying with my original dispute. They have stated that my account has been verified, even though I have paid off the account in full and it is closed. They are still showing late payments as false and inaccurate, which is affecting my consumer report and causing fluctuations in my credit score. This situation has been exhausting, with no justification or explanation from them. The CFPB states that if your account is current and you make an agreement to make a partial payment, skip a payment, or other accommodation, then the creditor is to report to credit reporting companies that you are current on your loan or account. If your account is already delinquent and you make an agreement, then the creditor can not report you as more delinquent (such as reporting you as 60 days delinquent when you started out 30 days delinquent). If your account is already delinquent and you make an agreement, and you bring your account current, the creditor must report that you are current on your loan or account. I have the documents proving that"}
#
# 2 {'generated_text': ' On XX/XX/2021, I placed a {$660.00} order on XXXX using my Citi credit card. The website stated that my order would ship out by the end of XXXX, and the return policy stated that customers could cancel and get an 100 % refund if their order was still not shipped 2 weeks after the estimated shipping date. \n\nOn XX/XX/2021, I emailed the XXXX requesting a refund ( in accordance with their Return Policy terms ), but they did not respond ( which is a known tactic they employ according to the customer feedback on their XXXX page ). \n\nOn XX/XX/2021, I opened a dispute with Citi related to the charge, and they issued a provisional credit to my account in the full amount. \n\nOn XX/XX/2021, I received a letter from Citi stating they have " closed our investigation and reversed our credit \'\', and referenced the merchant \'s response ( a " Chargeback Evidence \'\' PDF from Stripe that entirely lacks any information about the Refund Policy or shipment Tracking Number ). \n'}
#
# 3 {'generated_text': ' Banking complaint:\n\nI recently discovered that a Costco-issued Visa card in my name without my knowledge. It was never approved, and after I tried to cancel it for two months, an unauthorized charge was made. Despite my inquiries, the account was not reversed, and interest accumulated. This is not only frustrating but also negatively affecting my credit score. Please help me resolve this.'}
#
# 4 {'generated_text': ' "I have been dealing with Wells Fargo for the past couple of weeks, trying to show my loan as paid in full. Despite the fact that it was paid off 3 weeks ago, they refuse to update my credit report and still show it as open. I\'ve talked to several managers, but one manager in particular has been unhelpful and rude. She\'s been ignoring my requests to update the credit report and won\'t do anything until next month. I\'m trying to buy a house, but this balance is holding me back from getting approved. I\'m fed up with the lack of customer service and expect a more prompt resolution to this issue."'}
#
# 5 {'generated_text': " Complaint:\n\nTo whom it may concern,\n\nI am writing to express my extreme dissatisfaction with the service I received from WellsFargo Bank NAI. I had an account with them and on the month of XXXX XXXX, 2015, a fraudulent withdrawal of $5500.00 was made from my account without my authorization. I have tried to dispute the issue and file a claim, but the bank has been unresponsive and has not provided any explanation or resolution.\n\nI have provided all necessary documentation to the bank, including my bank card and PIN, and have been denied multiple times. Despite this, the bank has refused to give me any explanation or assistance in resolving the issue. I am requesting help in getting my money back and an explanation from the bank as to why they have not taken any action to rectify the situation.\n\nI have also filed a police report and am awaiting a response from them. I am extremely frustrated with the bank's lack of responsiveness and am requesting that you take immediate action to resolve this issue. I would appreciate a prompt response and an explanation as to why the bank has not provided any assistance."}
#
# 6 {'generated_text': " '''My account was closed for no reason. I received two checks from different banks, and next day my account was frozen and closed for cause. I had to call the check issuer and reissue the checks, which caused me a lot of inconvenience. Wells Fargo has informed XXXX that both my savings account and checking account were closed for cause, which prevented me from opening a new bank account. The banks are too quick to close accounts without any reasons, which affects many consumers negatively.'''"}
#
# 7 {'generated_text': " On XXXX XXXX 2016, I visited the Wells Fargo branch located at XXXX XXXX XXXX , XXXX, TX XXXX to make a deposit. Upon my arrival, I was greeted by a banker sitting at his desk. I told him that I was making a deposit, and he directed me to the teller line. I approached the teller, a white male, and told him I needed to make a deposit of some cash and a check. He asked for my debit card, which I provided him. I then entered my security PIN on the WF Point of Sale terminal. \n\nI opened a check ( {$220.00} ) that I had received from the United States Postal Service in front of him. He took the check, and I asked if I could receive a color copy. He said he could n't do a color copy, and instead asked if I wanted a B & W copy, to which I had declined. \n\nHe then proceeded to deposit the {$100.00} cash and asked if there was anything else I needed. I said no, and then the WF Point-"}
#
# 8 {'generated_text': ' Dear WellsFargo,\n\nI am writing to express my extreme dissatisfaction with the way my account was handled. On XX/XX/2019, I received a letter from your law firm for a total amount of {$190.00}. I understand that I owe money on a credit card, and I have tried to make payments, but my account has been taken from on several occasions.\n\nI have recieved no explanation for these charges, and the customer service was not helpful. I was told that the credit card was closed, but this does not explain why I was charged. I do not have this credit card, and there is no way for me to track the balance or make payments. The account is on my credit report as a write-off, and it is old. I have no way to contact the credit card holder.\n\nI have contacted your customer service multiple times, but the representative I spoke with was rude, not helpful, and referred me to someone else. She could not give me much information about the charges, and I felt like I was not being treated as a customer.\n\nI am shocked that your company would take money from both my checking and savings accounts without'}
#
# 9 {'generated_text': " '''Capital One: Unacceptable! You are still late on your credit card, 2 years later! I have been patient and have never been 30 days late on any of my credit cards. I am in the process of refinancing my home, but I am not eligible due to your inaction. I have requested forbearance and payment deferral for 2 months, and you approved it for another 2 months. I am not asking for anything I am just trying to get back on track with my finances. Please fix this issue immediately.'''"}
#
# 10 {'generated_text': ' I am deeply disappointed to hear that you are experiencing this issue with your Wells Fargo account. It is unacceptable that someone has been using your personal information without your authorization to apply for goods or services, and it is furthermore concerning that they were successful in creating new accounts in your name. I strongly advise you to take immediate action to protect your personal information and prevent any further unauthorized activity. I encourage you to report this incident to the Federal Trade Commission (FTC) and to contact your local bank to ensure that your accounts are secure. I apologize for any inconvenience this has caused and I am committed to helping you resolve this issue as quickly and efficiently as possible.'}
#
# CPU times: user 192 ms, sys: 11.6 ms, total: 203 ms
# Wall time: 1min 2s

# %%
# %%time 

for i in range(len(random_samples[0:10])):
    instructions = [
        {
            "role": "system",
            "content": "Your task is to generate short synthesized customer complaints from banks. \
            Provide modified samples",
        },
        {
            "role": "user",
            "content": f"""
            Develop a method to make complaints more harsh \
            while keeping the underlying issue intact in at most 50 words. 
            Make sure all sentences are complete.
            
            Complaints: '''{random_samples[i]}'''"""
        }
    ]
    prompt = format_instructions(instructions)
    payload = {
        "inputs": prompt,
        "parameters": {"max_length": 50, "max_new_tokens": 260, "temperature": 0.8, "top_p": 0.9}
    }
    response = query_endpoint(payload)
    
    print(i+1, response, "\n")
# Out:
# 1 {'generated_text': ' Dear Capital One Auto,\n\nI am writing to express my extreme dissatisfaction with the way you have handled my account. Despite my repeated attempts to dispute inaccuracies and disputes, you have not complied with my original disputes and have only stated that the account has been verified. This is completely unacceptable and has caused me a lot of stress and frustration.\n\nAdditionally, I have paid off the account in full and it is closed, yet you are still showing late payments that are inaccurate and false. This is affecting my consumer report and is playing a huge part in my credit score fluctuations. I am exhausted with this situation and not having any justification or explanations for the false reporting.\n\nThe Consumer Financial Protection Bureau states that if your account is current and you make an agreement to make a partial payment, skip a payment, or other accommodation, then the creditor is to report to credit reporting companies that you are current on your loan or account. If your account is already delinquent and you make an agreement, then the creditor can not report you as more delinquent (such as reporting you as 60 days delinquent when you started'}
#
# 2 {'generated_text': ' On XX/XX/2021, I placed a {$660.00} order on XXXX using my Citi credit card. The website stated that my order would ship out by the end of XXXX, and the return policy stated that customers could cancel and get an 100 % refund if their order was still not shipped 2 weeks after the estimated shipping date. \n\nOn XX/XX/2021, I emailed the XXXX requesting a refund ( in accordance with their Return Policy terms ), but they did not respond ( which is a known tactic they employ according to the customer feedback on their XXXX page ). \n\nOn XX/XX/2021, I opened a dispute with Citi related to the charge, and they issued a provisional credit to my account in the full amount. \n\nOn XX/XX/2021, I received a letter from Citi stating they have " closed our investigation and reversed our credit \'\', and referenced the merchant \'s response ( a " Chargeback Evidence \'\' PDF from Stripe that entirely lacks any information about the Refund Policy or shipment Tracking Number ). \n'}
#
# 3 {'generated_text': ' "Citi Visa fraud: A Costco-opened account without my knowledge was charged without my consent, and it has been going on for two months. I have tried to reverse it, but it has not been corrected. I have been charged interest, and this is affecting my credit score negatively. Please help me with the process of correcting this issue."'}
#
# 4 {'generated_text': ' This complaint is about an issue with Wells Fargo where they have refused to mark a loan as paid in full on a credit bureau despite the loan being paid off. The customer is upset about the lack of action from the bank and is trying to get the issue resolved as soon as possible. The customer is frustrated with the rude manager who refuses to help and is seeking a solution. \n\n'}
#
# 5 {'generated_text': ' Re: XXXX XXXX XXXX # XXXX XXXX XXXX XXXX XXXX XXXX, XXXX , fl XXXX ( XXXX ) XXXXXXXX\n\nAccount # XXXX WellsFargo Bank NAI\n\nTo whom it may concern,\n\nI am writing to express my extreme dissatisfaction with the recent fraudulent activity that occurred in my account. On the month of XXXX XXXX, 2015, a total of $5500.00 was withdrawn from my account without my authorization. As I am aware, I was overseas during this time period, and I believe that this transaction was made without my knowledge or consent.\n\nI have already filed a claim with the bank institution, WellsFargo Bank NA, and I have provided all the necessary documents to support my claim. However, despite my repeated efforts, I have received no answer or explanation from the bank. I have also filed a complaint with the police and have been denied any resolution or refund for the stolen funds.\n\nI am extremely frustrated and dismayed by the lack of action and communication from this institution. I am requesting immediate assistance to resolve this matter and'}
#
# 6 {'generated_text': ' I am very upset that my bank account was closed for no apparent reason. I had recently deposited two third-party checks, and the next day, my account was frozen and closed. I had to call the check issuer to have both checks re-issued. Wells Fargo reported to the FTC that both my savings account and checking account were closed for no cause, which has made it impossible for me to open a bank account. The banks are too quick to close accounts for suspected fraud, which causes consumers to suffer unnecessary financial hardship.'}
#
# 7 {'generated_text': " On XXXX XXXX 2016, I visited the Wells Fargo branch at XXXX XXXX XXXX , XXXX, TX XXXX to make a deposit. I was greeted by a banker who directed me to the teller line. I approached the teller, a white male, and told him I needed to make a deposit of some cash and a check. He asked for my debit card, which I provided him. I then entered my security PIN on the WF Point of Sale terminal.\n\nI opened a check ( {$220.00} ) that I had received from the United States Postal Service in front of him. He took the check, and I asked if I could receive a color copy. He said he could n't do a color copy, and instead asked if I wanted a B & W copy, to which I had declined.\n\nHe then proceeded to deposit the {$100.00} cash and asked if there was anything else I needed. I said no, and then the WF Point-of-Sale machine asked how I would like my receipt. I selected to have the receipt delivered electronically to"}
#
# 8 {'generated_text': ' Complaint:\n\n"On XX/XX/2019, WellsFargo withdrew a total of $950.00 from my checking and savings accounts without notice. This is a clear violation of my rights as a consumer and is unacceptable. I have tried to communicate with WellsFargo multiple times and have been met with rude and unhelpful customer service. I am in a difficult financial situation and cannot afford to have my accounts drained in this manner. I demand that WellsFargo take immediate action to rectify this situation and provide me with the funds I need to cover my expenses. If I do not hear from WellsFargo within the next 72 hours, I will be forced to take legal action to protect my rights as a consumer."\n\nComplaint:\n\n"WellsFargo has been a constant source of frustration and financial hardship for me. On XX/XX/2019, they withdrew $800.00 from my checking account and $600.00 from my savings account without any notice or explanation. This is a clear violation of my rights as a consumer and I demand that Well'}
#
# 9 {'generated_text': ' \'\'\'I\'ve been a loyal customer of Capital One for 10 years and have never been late on my credit card. However, due to the ongoing COVID-19 pandemic, I requested forbearance/payment deferral and was approved for a 2-month deferral. Unfortunately, in XXXX, 2020, Capital One failed to remove a 30-day late from my credit report, which dropped my FICO score by XXXX points. I\'ve tried contacting Capital One by phone and letter, but they refused to remove the late. I\'ve been denied refinancing my home due to the FICO score lowering, despite being "NOT ELIGIBLE" to complete the loan. Capital One, you have a serious issue with your credit reporting and customer service. I demand a full refund for the deferral and a prompt resolution to this matter.\'\'\''}
#
# 10 {'generated_text': " I am writing to express my frustration with the unauthorized use of my social security number and credit card information. I have been a customer of Wells Fargo for several years and have always been a loyal member of the bank's customer base. However, I recently discovered that someone has been using my personal information to open accounts in my name without my consent. This is not only a violation of my privacy and trust, but it has also resulted in me incurring unauthorized charges on my credit card and debiting my bank account. I am still investigating the matter and have not yet received any official response from Wells Fargo. I am extremely disappointed in the bank's handling of this situation and hope that they will take immediate action to rectify the issue. I demand that they provide a full refund for all unauthorized charges and immediately cancel all of the unauthorized accounts. I am also requesting a copy of any documents or records related to this incident. I will not hesitate to take legal action if necessary to protect my rights and prevent any further unauthorized use of my personal information. \n\nDear [Bank],\n\nI am writing to express my disappointment and fr"}
#
# CPU times: user 181 ms, sys: 13.5 ms, total: 194 ms
# Wall time: 1min 6s

# %%
# %%time 

for i in range(len(random_samples[0:10])):
    instructions = [
        {
            "role": "system",
            "content": "Your task is to generate short synthesized customer complaints from banks. \
            Provide modified samples",
        },
        {
            "role": "user",
            "content": f"""
            Develop a method to make complaints more harsh \
            while keeping the underlying issue intact in at most 50 words. 
            Make sure all sentences are complete.
            
            Complaints: '''{random_samples[i]}'''"""
        }
    ]
    prompt = format_instructions(instructions)
    payload = {
        "inputs": prompt,
        "parameters": {"max_length": 50, "max_new_tokens": 260, "temperature": 0.8, "top_p": 0.9}
    }
    response = query_endpoint(payload)
    
    print(i+1, response, "\n")
# Out:
# 1 {'generated_text': ' Sample Complaint:\n\n"Bank of America Auto is in clear violation of my consumer rights by ignoring my disputes of inaccuracies and not complying to my original dispute. Despite my efforts to resolve the issue, they have only stated that the account has been verified, but I have paid off the account in full and it is closed. They are still showing late payments that are inaccurate and false, which is affecting my consumer report and causing issues with promotions at work and trying to buy a home. I am extremely frustrated with this situation and need the creditor to take immediate action to correct the false reporting. The CFPB states that if your account is current and you make an agreement to make a partial payment, skip a payment, or other accommodation, then the creditor is to report to credit reporting companies that you are current on your loan or account. If your account is already delinquent and you make an agreement, then the creditor can not report you as more delinquent, and if your account is already delinquent and you make an agreement, and you bring your account current, the creditor must report that you are current on your loan or account. I have the documents prov'}
#
# 2 {'generated_text': ' XX/XX/2021, I placed a $660.00 order on XXXX using my Citi credit card. The website stated that my order would ship out by the end of XXXX, and the return policy stated that customers could cancel and get an 100% refund if their order was still not shipped 2 weeks after the estimated shipping date.\n\nOn XX/XX/2021, I emailed the XXXX requesting a refund, but they did not respond, which is a known tactic they employ according to the customer feedback on their XXXX page.\n\nOn XX/XX/2021, I opened a dispute with Citi related to the charge, and they issued a provisional credit to my account in the full amount.\n\nOn XX/XX/2021, I received a letter from Citi stating they have "closed our investigation and reversed our credit," and referenced the merchant\'s response (a "Chargeback Evidence" PDF from Stripe that entirely lacks any information about the Refund Policy or shipment Tracking Number).\n\nThe letter also stated that I could continue the dispute by providing "proof'}
#
# 3 {'generated_text': " '''Citi Visa card opened at Costco without my authorization. When I attempted to cancel it, I was charged without my consent. It has been five months since I opened the account, and the charges have not been reversed. Moreover, interest has been accumulating. The neglect by Citi Visa has had a negative impact on my credit score. Please assist me in resolving this matter.'''"}
#
# 4 {'generated_text': ' Here are five modified customer complaints against Wells Fargo, each with a new name for the bank representative:\n\n1. "I\'ve been with Wells Fargo for three weeks, and my loan has been paid in full for three weeks. I\'ve tried to contact multiple managers, but they keep telling me that I need to wait until next month to have the payment marked as paid in full. I need this cleared up as soon as possible, as I\'m trying to buy a house and the fact that my credit is still open and I owe a significant amount is making it difficult. I\'ve been rude with my representatives, but they won\'t budge. I need a resolution as soon as possible."\n2. "I\'ve been a loyal customer of Wells Fargo for years, but their incompetence has finally caught up to them. I recently paid off my loan, and even though I\'ve tried to contact them multiple times, they refuse to mark it as paid in full. I\'ve had to deal with multiple managers, but they\'ve all been unresponsive and unhelpful. I\'m at my wit\'s end, and I need this issue resolved as soon as'}
#
# 5 {'generated_text': ' Here are five modified synthetic customer complaints against WellsFargo Bank:\n\n1. To whom it may concern,\n\nRe: XXXX XXXX XXXX # XXXX XXXX XXXX XXXX XXXX XXXX, XXXX, fl XXXX (XXXX) XXXXXXXX\n\nI am writing to express my dissatisfaction with the fraudulent transactions that took place in my account on the month of XXXX XXXX, 2015. I have filed a claim with WellsFargo Bank NAI, and despite my efforts to resolve the issue, I have yet to receive a satisfactory response. I have provided all supporting documents, but the bank has failed to address my concerns. I am requesting help to get my money back and an explanation for the delay in my claim.\n\n2. Dear [Bank Representative],\n\nI am writing to complain about the fraudulent activities that took place in my WellsFargo Bank account on the month of XXXX XXXX, 2015. I have filed a claim with your institution, and despite my efforts to resolve the issue, I have yet to receive a satisfactory response. I have provided all supporting documents'}
#
# 6 {'generated_text': ' My account was closed for no reason. I received two checks from different banks, but the next day, my account was frozen and closed for cause. I had to call the check issuer to have the checks re-issued, and Wells Fargo reported to XXXX that my savings account and checking account were closed for cause. The banks are too quick to close for suspected fraud, which is causing many consumers to lose access to their bank accounts.'}
#
# 7 {'generated_text': ' Complaint 1:\n\nOn 01/01/2022, I visited the Wells Fargo branch at 123 Main St, Anytown, USA to make a deposit. The teller informed me that I needed to open a new account to deposit my money. I explained that I already had an account and was unable to find my account information. The teller asked me to provide my ID and PIN, which I did. However, the system showed an error message stating that I had already used this PIN for another account. I was unable to resolve the issue and had to leave the branch.\n\nComplaint 2:\n\nI recently visited the Wells Fargo branch at 456 Elm St, Anytown, USA to deposit a check. The teller asked me for my ID and PIN, which I provided. However, the system showed an error message stating that my PIN had been used for a check deposit within the past 30 days. I explained that I had not deposited a check in the past 30 days, but the teller was unresponsive and told me to visit the branch manager.\n\nComplaint 3'}
#
# 8 {'generated_text': ' On XX/XX/2019, WellsFargo withdrew {$390.00} from my checking account and {$560.00} from my savings account. When I called them that evening, the customer service was very nice but unhelpful. She could not tell me much about the charges, except that they were for a closed credit card.\n\n1. This credit card is not linked to my account.\n2. This credit card does not allow me to track my payments or account balance.\n3. This account is on my credit report as a write-off.\n4. This account is old and I do not have the card number.\n5. When I called in the past, the customer service could not find any information about the account.\n\nI have received one letter in the last year from the law group WellsFargo is using to sue me for a total amount of {$190.00}. I understand that I owe the amount on the credit card and that payment arrangements need to be made. However, I communicated with [name] [date] that I am low-income, making less than {$2000.00}'}
#
# 9 {'generated_text': ' "Unfair treatment by Capital One in XXXX, 2020 due to COVID-19. Requested forbearance/payment deferral was approved for 2 months, yet Capital One refused to remove a 30 day late from my credit report, which lowered my FICO score by XXXX points. I have never been late on ANY of my credit cards before and I am in the process of refinancing my home. The FICO score lowering made me \'NOT ELIGIBLE\' to complete the refinance loan. I have been with Capital One for 10 years and have never been late. Capital One\'s actions are unacceptable and I am seeking justice. Please help."'}
#
# 10 {'generated_text': " '''My name is XXXX XXXX this complaint is not made in error neither is it being made by a third party. I declare under penalty of perjury I am alleging that a person or company- without my authorization- from unauthorized use of my social security number and card used my personal identifying information to apply for goods, services, or money ; and, was successful in creating some accounts. I have no knowledge of this and all is being investigated by the FTC and Under 15 U.S. Code 1681b Permissible purposes of consumer reports I never gave any written consent to report anything on my consumer reportsno consent is fraud. WF/XXXX  XXXX Date Open : XX/XX/XXXX Balance : {$24000.00} and WELLS FARGO XXXX Date Open : XX/XX/XXXX Balance : {$1800.00}.'''\n\n\n"}
#
# CPU times: user 188 ms, sys: 6.57 ms, total: 195 ms
# Wall time: 1min 8s

# %%
# %%time 

for i in range(len(random_samples[0:10])):
    instructions = [
        {
            "role": "system",
            "content": "Your task is to generate short synthesized customer complaints from banks. \
            Provide modified samples",
        },
        {
            "role": "user",
            "content": f"""
            Develop a method to make complaints more harsh \
            while keeping the underlying issue intact in at most 50 words. 
            Make sure all sentences are complete.
            
            Complaints: '''{random_samples[i]}'''"""
        }
    ]
    prompt = format_instructions(instructions)
    payload = {
        "inputs": prompt,
        "parameters": {"max_length": 50, "max_new_tokens": 260, "temperature": 0.8, "top_p": 0.9}
    }
    response = query_endpoint(payload)
    
    print(i+1, response, "\n")
# Out:
# 1 {'generated_text': ' Sample modified complaint:\n\n"Bank of America is violating my consumer rights by disregarding my disputes and not complying to my original dispute. They have reported my account as late when I have paid it off in full and it is closed. They are still showing late payments that are inaccurate and false, which is affecting my credit score and causing problems for me at work and when trying to buy a home. I am extremely frustrated with this situation and am tired of not having any justification or explanation for the false reporting. The CFPB states that if your account is current and you make an agreement to make a partial payment, skip a payment, or other accommodation, then the creditor must report to credit reporting companies that you are current on your loan or account. However, Bank of America has continued to report my account as late despite my agreements, which is a violation of my rights."'}
#
# 2 {'generated_text': ' Here are five modified customer complaints about bank disputes, each with a harsher tone while maintaining the underlying issue:\n\n1. "It\'s unacceptable that I had to wait for two weeks for a response from Citi after requesting a refund. The lack of transparency and communication is unprofessional and unacceptable. I will not be using Citi for any future transactions."\n2. "The fact that Citi didn\'t respond to my request for a refund within the given time frame is a slap in the face. They expect me to blindly follow their rules and regulations, but they fail to follow their own policies. I will not be using Citi for any future transactions."\n3. "I\'m outraged that Citi closed our investigation without resolving the issue. I provided all the necessary documentation and evidence, but they still failed to provide a refund. I will not be using Citi for any future transactions."\n4. "The lack of communication and transparency from Citi is unacceptable. They have no regard for their customers and their policies. I will not be using Citi for any future transactions."\n5. "I\'m fed up with'}
#
# 3 {'generated_text': " '''Citibank failed to properly supervise and monitor Costco's actions in opening a visa account without my authorization. After I attempted to cancel the account twice, a charge was made without my authorization, and the reversal was not honored. It took over five months to address this neglect, and now I am owed interest on the account, which will negatively impact my credit score. Please assist me in resolving this issue.'''"}
#
# 4 {'generated_text': " Complaint: \n\nSo I have been dealing with Wells Fargo for the last couple of weeks. I had my loan paid in full 3 weeks ago, but they refuse to mark it paid in full on the credit bureau. I have dealt with a couple of managers, and this XXXX XXXX thinks she is god and won't report it until next month. I'm trying to buy a house, and I need this balance gone from my credit report. I'm upset they won't report this correctly with the credit bureaus, and I want this done ASAP. This XXXX XXXX is very rude and won't lift a finger to help. The credit still shows open and I owe XXXX. It should be XXXX, but they still won't do it."}
#
# 5 {'generated_text': " I am writing this letter to complain about the inadequate service I received from WellsFargo Bank NAI. I was an international traveler and made a withdrawal from my account in XXX at XXXX XXX, 2015, without my permission. My account was drained of $5500.00 without my knowledge or consent. The bank declined my claim for the money, stating that I was not in the country at the time of the transaction.\n\nI have filed multiple claims with the bank, but they have repeatedly denied them. Despite providing all required documents, I have not received any response or resolution. The bank's lack of transparency and incompetence in handling my case is unacceptable.\n\nI am requesting immediate assistance and an explanation for the delay in resolving my claim. I would also like to know the steps the bank is taking to prevent similar fraudulent transactions in the future.\n\nI have attached all supporting documents to this letter. I am frustrated and dissatisfied with the service I have received, and I hope that WellsFargo Bank NAI will take my complaint seriously and provide a satisfactory response.\n\nSincer"}
#
# 6 {'generated_text': " Complaints: '''I can't believe my account was closed for cause. I had two checks from third parties deposited and the next day my account was frozen and closed for cause. I had to call the check issuer and have both checks re-issued. Wells Fargo has reported to my local bank that both my savings account and checking account were closed for cause, which has caused me to be unable to open a bank account. The banks are too quick to close for suspected fraud, which is causing many consumers unnecessary inability to open a bank account.'''"}
#
# 7 {'generated_text': ' I\'m sorry, but I cannot satisfy your request. I cannot create a method to make complaints more harsh while keeping the underlying issue intact in at most 50 words. All sentences must be complete.\n\nComplaints: \'\'\'On XXXX XXXX 2016, I \'d visited the Wells Fargo ( " WF \'\' ) branch located at XXXX XXXX XXXX , XXXX, TX XXXX to make a deposit. \n\nUpon my arrival, I was greeted by a banker sitting at his desk. I told him that I was making a deposit, and he directed me to the teller line. I approached the teller, a white male, and told him I needed to make a deposit of some cash and a check. He asked for my debit card, which I provided him. I then entered my security PIN on the WF Point of Sale terminal. \n\nI opened a check ( {$220.00} ) that I had received from the United States Postal Service in front of him. He took the check, and I asked if I could receive a color copy. He said he could n\'t do'}
#
# 8 {'generated_text': ' Complaint 1:\n\n"I am outraged and frustrated by the recent withdrawal of {$390.00} from my checking and {$560.00} from my savings account without my knowledge or consent. The customer service representative I spoke with was not helpful or transparent about the charges, and I was left feeling confused and betrayed. I demand a full refund of these funds and an explanation for how this happened. I have been a loyal customer of WellsFargo for many years, and I expect better service.\n\nComplaint 2:\n\n"I am appalled by the actions of WellsFargo in taking {$190.00} from my account without my permission. I understand that I owe money on a credit card, but I do not understand how the bank can take this amount without any regard for my financial situation. I have been a victim of predatory lending and have been struggling to make ends meet. I cannot believe that WellsFargo would take advantage of my situation like this. I demand a full refund of the funds taken and an investigation into how this happened. I will not be able to pay my bills until this issue is'}
#
# 9 {'generated_text': ' I requested forbearance/payment deferral with Capital One in XXXX, 2020 due to COVID-19 and was approved for a 2 month deferral to XXXX, 2020. However, in XXXX, 2020 Capital One showed a 30 day late on my credit report which lowered my FICO score XXXX points. (I had requested the same with 8 other credit card companies and was approved with all). I, immediately contacted Capital One, by phone and letter, and they refused to remove the 30 day late. I have never been 30 days late on ANY of my credit cards and was in the process of refinancing my home. The FICO score lowering made me " NOT ELIGIBILE \'\' to complete the refinance loan. I have been with Capital One for 10 years and have never been late. Please help and I want my credit score back.'}
#
# 10 {'generated_text': ' Dear [Bank Name],\n\nI am writing to express my extreme dissatisfaction with the unauthorized use of my social security number and credit card information. I recently discovered that someone has been using my personal information to apply for credit in my name without my consent. This is not only a violation of my privacy, but it has also resulted in several new accounts being opened in my name, which I have no knowledge of.\n\nI demand that you take immediate action to correct this issue and protect my personal information. I expect a full investigation into this matter and the steps you will take to prevent any further unauthorized use of my personal information. I also expect a prompt resolution of this issue and a satisfactory explanation for the unauthorized use of my credit and social security number.\n\nI am contacting you today to make a formal complaint and to request that you take immediate action to address this issue. I expect a response to this complaint within 10 business days and a resolution to this issue within 20 business days.\n\nSincerely,\n\n[Your Name]'}
#
# CPU times: user 182 ms, sys: 19.8 ms, total: 201 ms
# Wall time: 1min 7s

# %%
# %%time 

for i in range(len(random_samples[0:10])):
    instructions = [
        {
            "role": "system",
            "content": "Your task is to generate short synthesized customer complaints from banks. \
            Provide modified samples",
        },
        {
            "role": "user",
            "content": f"""
            Develop a method to make complaints more harsh \
            while keeping the underlying issue intact in at most 50 words. 
            Make sure all sentences are complete.
            
            Complaints: '''{random_samples[i]}'''"""
        }
    ]
    prompt = format_instructions(instructions)
    payload = {
        "inputs": prompt,
        "parameters": {"max_length": 50, "max_new_tokens": 260, "temperature": 0.8, "top_p": 0.9}
    }
    response = query_endpoint(payload)
    
    print(i+1, response, "\n")
# Out:
# 1 {'generated_text': " Capital One Auto is a complete disgrace to the banking industry. They have consistently disregarded my disputes regarding inaccuracies in their reports, and have failed to comply with my original disputes. Despite being fully paid off and closed, they continue to report late payments that are false and inaccurate. This is causing significant damage to my credit score, impacting my ability to obtain credit, and making it difficult for me to buy a home. I am extremely frustrated with their lack of transparency and accountability. They have repeatedly broken the CFPB's rules by reporting late payments that I have already made arrangements to make. I demand they take immediate action to correct this false reporting and delete all late payments from their report. I am extremely disappointed with the quality of service I have received from Capital One Auto."}
#
# 2 {'generated_text': ' On 01/01/2021, I placed a $660.00 order on XYZ using my Citi credit card. The website stated that my order would ship out by the end of 2021, and the return policy stated that customers could cancel and get an 100% refund if their order was still not shipped 2 weeks after the estimated shipping date.\n\nOn 01/01/2021, I emailed the XYZ requesting a refund (in accordance with their Return Policy terms), but they did not respond (which is a known tactic they employ according to the customer feedback on their XYZ page).\n\nOn 01/01/2021, I opened a dispute with Citi related to the charge, and they issued a provisional credit to my account in the full amount.\n\nOn 01/01/2021, I received a letter from Citi stating they have "closed our investigation and reversed our credit," and referenced the merchant\'s response (a "Chargeback Evidence" PDF from Stripe that entirely lacks any information'}
#
# 3 {'generated_text': ' Visa account opened via Costco without authorization. Cancelled twice without reversal, accumulated interest. Neglect by Citi resulted in credit score damage. Please help correct the error.'}
#
# 4 {'generated_text': ' Complaint: "I\'ve been with Wells Fargo for months now, trying to get my loan paid off. I\'ve dealt with multiple managers and this XXXX XXXX thinks they\'re some kind of god. They refuse to report my loan as paid in full on my credit bureau, even though it\'s been over a month since I paid it off. I\'m trying to buy a house and this balance is holding me back. I\'ve been told to wait until next month to get it reported, which is unacceptable. I\'m very upset and want this done ASAP. This XXXX XXXX is rude and won\'t do anything to help me."'}
#
# 5 {'generated_text': ' Dear WellsFargo Bank,\n\nI am writing to express my extreme dissatisfaction with the fraudulent activity that took place on my account. On the month of XXXX XXXX, 2015, a total of {$5500.00} was withdrawn from my account without my authorization. I had been informed that I was overseas at the time of this transaction, but this excuse was not sufficient to cover the amount.\n\nI filed a claim with your institution, but it has taken over six months to receive a response. Despite my repeated requests for a refund and explanation for the fraudulent activity, I have been met with only excuses and evasions. The bank has denied my claim, stating that I am responsible for the unauthorized transactions.\n\nI am outraged that my account was compromised and I have been denied compensation for my losses. I am requesting that you take immediate action to rectify this situation and provide a full refund to me. I am also demanding that you provide an explanation for the fraudulent activity and take appropriate action against the individuals or entities involved.\n\nI have attached all of my supporting documents'}
#
# 6 {'generated_text': ' Here are five possible revised customer complaints against banks, each with a tone that is harsher than the original while maintaining the underlying issue:\n\n1. "How dare you close my account for no reason? I trusted you with my money and now you\'ve taken it away from me without a second thought. You\'re the worst bank ever and I\'ll never trust you again."\n2. "I can\'t believe you\'re just going to close my account without even bothering to investigate. You\'re not a bank, you\'re a money-sucking monster. I demand that you reopen my account or face the consequences."\n3. "You\'re not a bank, you\'re a fraudulent organization that preys on the naive. I\'m never going to use your services again and I\'ll make sure everyone I know knows about your terrible reputation."\n4. "You\'re so dishonest and untrustworthy. I\'m not surprised that my account was closed without a second thought. You\'re a joke and I\'ll never give you my money again."\n5. "You\'re the worst bank I\'ve ever de'}
#
# 7 {'generated_text': " Complaint:\n\nI visited the Wells Fargo branch located at XXXX XXXX XXXX, XXXX, TX XXXX on XXXX XXXX 2016 to make a deposit. Upon my arrival, I was greeted by a banker at his desk. I told him that I was making a deposit, and he directed me to the teller line. I approached the teller, a white male, and told him I needed to make a deposit of some cash and a check. He asked for my debit card, which I provided him. I then entered my security PIN on the WF Point of Sale terminal. \n\nI opened a check ({$220.00}) that I had received from the United States Postal Service in front of him. He took the check, and I asked if I could receive a color copy. He said he couldn't do a color copy, and instead asked if I wanted a B&W copy, to which I had declined. \n\nHe then proceeded to deposit the {$100.00} cash and asked if there was anything else I needed. I said no, and then the WF"}
#
# 8 {'generated_text': ' The following are modified customer complaints from banks:\n\n1. On the evening of XX/XX/2019, XXXXXXX took $390.00 from my checking and $560.00 from my savings account without my knowledge or consent. I was shocked and dismayed when I realized the mistake. I had contacted customer service that evening, but the representative was unhelpful and dismissive of my concerns. She could not provide me with any information about the charges, even though it was for a credit card that had been closed.\n\n2. This credit card does not appear on my account, and I do not receive any paperwork or statements regarding this account. I do not have access to this account, and it is listed as a write-off on my credit report. I have tried to dispute the charges, but the customer service representative was not helpful and did not provide me with any information.\n\n3. I have tried to communicate with WellsFargo several times, but the customer service representative was rude and unhelpful. She could not provide me with any information about my account, and she did not offer any solutions to my problems. I was left feeling frustrated and confused'}
#
# 9 {'generated_text': ' Dear Capital One,\n\nI am writing to express my extreme dissatisfaction with the way you handled my request for forbearance/payment deferral due to COVID-19. I had requested this for 2 months and was approved for a 2 month deferral. However, when I went to make a payment, I was told that I had a 30 day late on my credit report. This is completely unacceptable as I have never been late on any of my credit cards. I have contacted you by phone and letter, and yet, you refused to remove the 30 day late.\n\nI am also extremely frustrated that my FICO score was lowered by 8 points due to this late. I have never been late on any of my credit cards and this is not acceptable. I have been with Capital One for 10 years and have never been late. I am not sure how this happened, but it is completely unfair.\n\nI am not sure what you expect me to do now. I cannot complete my refinance loan because of the late on my credit report. I am at a loss as to what to do. I am not sure if there is any way to resolve this issue'}
#
# 10 {'generated_text': ' Dear [Bank Name],\n\nI am writing to express my extreme dissatisfaction with the unauthorized use of my social security number and credit card information. I have been the victim of identity theft and have had my personal information used to apply for credit and debit cards. I have no knowledge of this and it has caused me significant financial and emotional distress.\n\nI am requesting that you take immediate action to prevent any further unauthorized use of my personal information and to protect my credit and financial accounts. I am also demanding that you issue a full refund for any unauthorized charges that have been made in my name.\n\nI have attached a copy of the reports that I have received from the Federal Trade Commission and Under 15 U.S. Code 1681b. These reports show that my personal information was used without my consent and that I have been subjected to fraudulent activity.\n\nI am also requesting that you take steps to ensure that my personal information is not used for any future unauthorized purposes. I have faith in the security and integrity of your bank and I expect you to do everything in your power to protect me and my personal information.'}
#
# CPU times: user 188 ms, sys: 3.76 ms, total: 192 ms
# Wall time: 1min 11s
